# %%
import csv
import MySQLdb
import sys
import os
import subprocess
import genCSV as gc

# %%
# Class kernel
class kernel:

    def __init__(self, entry):
        self.entry = entry

    def get_cid(self):
        return str(self.entry[0])

    def get_entry(self):
        return self.entry

    def kernel2csv(self):
        try:
            final = list([self.entry[0]] + [str(self.entry[1])] + [str(self.entry[2])] + [self.entry[7]])
            compressed = self.entry[8].split(" , ")
            parse_array = [i.split(" : ") for i in compressed]
            cprss = [fin[1] for fin in parse_array]
            final += cprss

            return final
        except Exception as e:
            #print("Entry len:", len(self.entry))
            print("\n" + str(e))
            exit(-1)

# %%
# Virtual machine IP adress
HOST            = "148.60.11.195"

## MySQL user
DB_USER         = "script2"

## MySQL password
DB_PASSWD       = "ud6cw3xNRKnrOz6H"

# %%
# Create a new kernel instance from the physical kernel
def compute_kernel(cid):
    print("\nComputing range of cid...", flush=True)
    kernels_array = []
    
    try:
        socket = MySQLdb.connect(HOST, DB_USER, DB_PASSWD, "IrmaDB_prod")
        cursor = socket.cursor()
        
        for c in cid:
            query = "SELECT * FROM Compilations WHERE cid = %d and incremental_mod = 0" % c
            cursor.execute(query)
            entry = cursor.fetchone()
            
            if entry is not None:
                kernels_array.append(kernel(entry))
    
    except Exception as e:
        print(str(e),"\n" + "Unable to connect to database c = " + str(c), file=sys.stderr)
        exit(-1)
        
    finally:
        cursor.close()
        socket.close()
    
    return kernels_array

# %%
def create_header():

    conn = MySQLdb.connect(HOST, DB_USER, DB_PASSWD, "IrmaDB_prod")
    cursor = conn.cursor()

    get_prop = "SELECT name, type FROM Properties"
    # Extract properties
    cursor.execute(get_prop)
    types_results = list(cursor.fetchall())

    if len(types_results) == 0:
        print("\nError : Properties not present in database - You need to run Kanalyser first (https://github.com/TuxML/Kanalyser)")

    cursor.close()
    conn.close()

    # .config column names
    names = [""]*len(types_results)
    index = 0
    for (name, typ) in types_results:
        if name not in names:
            names[index] = name
            index += 1

    with open("config_bdd.csv", "w") as f:
        head = ("cid,date,time,vmlinux,GZIP-bzImage,GZIP-vmlinux,GZIP,BZIP2-bzImage,BZIP2-vmlinux,BZIP2,LZMA-bzImage,LZMA-vmlinux,LZMA,XZ-bzImage,XZ-vmlinux,XZ,LZO-bzImage,LZO-vmlinux,LZO,LZ4-bzImage,LZ4-vmlinux,LZ4," + ",".join(names)).split(",")
        writer = csv.DictWriter(f, head)
        writer.writeheader()

# %%
def to_csv(From, To):    
    values = gc.genCSV(0, From, To, incremental=False)
    
    # Correction for range(From, To) in order to have at least one value
    if From == To:
        To += 1

    cid_array = [c for c in range(From, To)]
    kernels_array = compute_kernel(cid_array)
    
    with open("config_bdd.csv", "a") as csv_file:
        writer = csv.writer(csv_file)
        
        if len(kernels_array) == 1:
            entry_val = kernels_array[0].kernel2csv()
            entry = entry_val + values[0]
            writer.writerow(entry)
        else:

            for num, k in enumerate(kernels_array):
                try:
                    entry_val = k.kernel2csv()
                    entry = entry_val + values[num]
                    #print("value:", values[num][7568])
                    writer.writerow(entry)
                except Exception as e:
                    print("Error at num:", num, flush=True)
                    print(str(e), flush=True)
                    exit(-1)

# %%
import bz2

def print_logs_configurations(cid):
    print("Printing logs of cid=", cid)
    
    try:
        socket = MySQLdb.connect(HOST, DB_USER, DB_PASSWD, "IrmaDB_prod")
        cursor = socket.cursor()

        query = "SELECT stdlog_file, errlog_file, output_file FROM Compilations WHERE cid = %d" % cid
        cursor.execute(query)
        stdlog_file, errlog_file, output_file = cursor.fetchone()
            
        if (stdlog_file is None) or (errlog_file is None) or (output_file is None):
            print ("Unable to retrieve cid...")
            return
        
        print("STD LOG FILE")
        print(bz2.decompress(stdlog_file).decode('ascii'))
        print("#########")
        print("ERR LOG FILE")
        print("#########")
        print(bz2.decompress(errlog_file).decode()) # not ascii? 
        print("#########")
        print("OUTPUT LOG FILE")
        print("#########")
        print(bz2.decompress(output_file).decode('ascii'))
    
    except Exception as e:
        print(str(e),"\n" + "Unable to connect to database c = " + str(c), file=sys.stderr)
        exit(-1)
        
    finally:
        cursor.close()
        socket.close()

print_logs_configurations(116732) #78749: WANXL_BUILD_FIRMWARE # 79052 AIC7XXX_BUILD_FIRMWARE
# Out:
# Printing logs of cid= 116732
# STD LOG FILE
# 00:00:00 make: Entering directory '/TuxML/linux-4.13.3'
# 00:00:02 scripts/kconfig/conf  --silentoldconfig Kconfig
# 00:00:04   SYSTBL  arch/x86/entry/syscalls/../../include/generated/asm/syscalls_32.h
# 00:00:04   SYSHDR  arch/x86/entry/syscalls/../../include/generated/asm/unistd_32_ia32.h
# 00:00:04   SYSHDR  arch/x86/entry/syscalls/../../include/generated/asm/unistd_64_x32.h
# 00:00:04   SYSTBL  arch/x86/entry/syscalls/../../include/generated/asm/syscalls_64.h
# 00:00:04   SYSHDR  arch/x86/entry/syscalls/../../include/generated/uapi/asm/unistd_32.h
# 00:00:04   SYSHDR  arch/x86/entry/syscalls/../../include/generated/uapi/asm/unistd_64.h
# 00:00:04   SYSHDR  arch/x86/entry/syscalls/../../include/generated/uapi/asm/unistd_x32.h
# 00:00:04   HOSTCC  scripts/basic/bin2c
# 00:00:04   CHK     include/config/kernel.release
# 00:00:04   UPD     include/config/kernel.release
# 00:00:04   CHK     include/generated/uapi/linux/version.h
# 00:00:04   UPD     include/generated/uapi/linux/version.h
# 00:00:04   CHK     include/generated/utsrelease.h
# 00:00:04   UPD     include/generated/utsrelease.h
# 00:00:06   HOSTCC  arch/x86/tools/relocs_32.o
# 00:00:06   HOSTCC  arch/x86/tools/relocs_64.o
# 00:00:06   HOSTCC  arch/x86/tools/relocs_common.o
# 00:00:06   WRAP    arch/x86/include/generated/asm/clkdev.h
# 00:00:06   WRAP    arch/x86/include/generated/asm/dma-contiguous.h
# 00:00:06   WRAP    arch/x86/include/generated/asm/early_ioremap.h
# 00:00:06   WRAP    arch/x86/include/generated/asm/mcs_spinlock.h
# 00:00:06   WRAP    arch/x86/include/generated/asm/mm-arch-hooks.h
# 00:00:06   HOSTCC  scripts/genksyms/genksyms.o
# 00:00:06   SHIPPED scripts/genksyms/parse.tab.c
# 00:00:06   SHIPPED scripts/genksyms/lex.lex.c
# 00:00:06   HOSTCC  scripts/kallsyms
# 00:00:06   CC      scripts/mod/empty.o
# 00:00:06   HOSTCC  scripts/mod/mk_elfconfig
# 00:00:06   HOSTCC  scripts/sortextable
# 00:00:06   SHIPPED scripts/genksyms/keywords.hash.c
# 00:00:06   CC      scripts/mod/devicetable-offsets.s
# 00:00:06   HOSTCC  scripts/asn1_compiler
# 00:00:06   HOSTLD  arch/x86/tools/relocs
# 00:00:06   MKELF   scripts/mod/elfconfig.h
# 00:00:06   HOSTCC  scripts/mod/modpost.o
# 00:00:06   HOSTCC  scripts/mod/sumversion.o
# 00:00:07   CHK     scripts/mod/devicetable-offsets.h
# 00:00:07   SHIPPED scripts/genksyms/parse.tab.h
# 00:00:07   HOSTCC  scripts/genksyms/parse.tab.o
# 00:00:07   UPD     scripts/mod/devicetable-offsets.h
# 00:00:07   CC      kernel/bounds.s
# 00:00:07   HOSTCC  scripts/mod/file2alias.o
# 00:00:07   HOSTCC  scripts/genksyms/lex.lex.o
# 00:00:07   CHK     include/generated/timeconst.h
# 00:00:07   UPD     include/generated/timeconst.h
# 00:00:07   CHK     include/generated/bounds.h
# 00:00:07   UPD     include/generated/bounds.h
# 00:00:07   CC      arch/x86/kernel/asm-offsets.s
# 00:00:08   HOSTLD  scripts/mod/modpost
# 00:00:08   HOSTLD  scripts/genksyms/genksyms
# 00:00:10   CHK     include/generated/asm-offsets.h
# 00:00:10   UPD     include/generated/asm-offsets.h
# 00:00:10   CALL    scripts/checksyscalls.sh
# 00:00:10   CC      init/main.o
# 00:00:10   CHK     include/generated/compile.h
# 00:00:10   CC      init/do_mounts.o
# 00:00:10   CC      init/do_mounts_initrd.o
# 00:00:10   CC      init/initramfs.o
# 00:00:10   CC      init/calibrate.o
# 00:00:10   CC      init/init_task.o
# 00:00:10   UPD     include/generated/compile.h
# 00:00:10   HOSTCC  usr/gen_init_cpio
# 00:00:10   CC      arch/x86/crypto/glue_helper.o
# 00:00:11   AS      arch/x86/entry/entry_64.o
# 00:00:11   GEN     usr/initramfs_data.cpio
# 00:00:11   AS      arch/x86/entry/thunk_64.o
# 00:00:11   AS      usr/initramfs_data.o
# 00:00:11   AR      usr/built-in.o
# 00:00:11   CC      arch/x86/entry/syscall_64.o
# 00:00:11   CC      arch/x86/events/core.o
# 00:00:11   CC      arch/x86/entry/common.o
# 00:00:11   CC      arch/x86/events/amd/core.o
# 00:00:12   CC      arch/x86/entry/vdso/vma.o
# 00:00:12   CC      arch/x86/entry/vdso/vdso32-setup.o
# 00:00:12   AS      arch/x86/crypto/aes-x86_64-asm_64.o
# 00:00:12   CC      arch/x86/crypto/aes_glue.o
# 00:00:12   CC      arch/x86/events/amd/uncore.o
# 00:00:12   AS      arch/x86/crypto/camellia-x86_64-asm_64.o
# 00:00:12   CC      arch/x86/crypto/camellia_glue.o
# 00:00:12   CC      arch/x86/events/amd/ibs.o
# 00:00:12   CC      arch/x86/entry/vsyscall/vsyscall_gtod.o
# 00:00:12   LDS     arch/x86/entry/vdso/vdso.lds
# 00:00:12   AS      arch/x86/entry/vdso/vdso-note.o
# 00:00:12   CC      arch/x86/entry/vdso/vclock_gettime.o
# 00:00:13   CC [M]  arch/x86/events/amd/power.o
# 00:00:13   CC      init/version.o
# 00:00:13   AR      arch/x86/entry/vsyscall/built-in.o
# 00:00:13   AS      arch/x86/entry/entry_64_compat.o
# 00:00:13   CC      arch/x86/entry/vdso/vgetcpu.o
# 00:00:13   CC      arch/x86/ia32/sys_ia32.o
# 00:00:13   CC      arch/x86/kernel/process_64.o
# 00:00:13   CC      arch/x86/kernel/signal.o
# 00:00:13   AR      init/mounts.o
# 00:00:13   AR      init/built-in.o
# 00:00:13   CC      arch/x86/kernel/signal_compat.o
# 00:00:13   HOSTCC  arch/x86/entry/vdso/vdso2c
# 00:00:13   AS      arch/x86/crypto/twofish-x86_64-asm_64.o
# 00:00:13   CC      arch/x86/kernel/traps.o
# 00:00:13   AR      arch/x86/events/amd/built-in.o
# 00:00:13   CC      arch/x86/events/intel/core.o
# 00:00:13   CC      arch/x86/crypto/twofish_glue.o
# 00:00:13   LDS     arch/x86/entry/vdso/vdso32/vdso32.lds
# 00:00:13   CC      arch/x86/entry/vdso/vdso32/vclock_gettime.o
# 00:00:13   AS      arch/x86/entry/vdso/vdso32/note.o
# 00:00:14   CC      arch/x86/ia32/ia32_signal.o
# 00:00:14   CC      arch/x86/mm/init.o
# 00:00:14   AS      arch/x86/crypto/twofish-x86_64-asm_64-3way.o
# 00:00:14   AR      arch/x86/net/built-in.o
# 00:00:14   CC      arch/x86/entry/syscall_32.o
# 00:00:14   AR      arch/x86/platform/atom/built-in.o
# 00:00:14   CC      arch/x86/crypto/twofish_glue_3way.o
# 00:00:14   AR      arch/x86/platform/ce4100/built-in.o
# 00:00:14   CC      arch/x86/platform/efi/quirks.o
# 00:00:14   AS      arch/x86/entry/vdso/vdso32/system_call.o
# 00:00:14   AS      arch/x86/entry/vdso/vdso32/sigreturn.o
# 00:00:14   AR      arch/x86/platform/geode/built-in.o
# 00:00:14   CC      arch/x86/platform/efi/efi.o
# 00:00:14   VDSO    arch/x86/entry/vdso/vdso64.so.dbg
# 00:00:14   CC      arch/x86/kernel/irq.o
# 00:00:14   CC [M]  arch/x86/ia32/ia32_aout.o
# 00:00:14   VDSO    arch/x86/entry/vdso/vdso32.so.dbg
# 00:00:14   OBJCOPY arch/x86/entry/vdso/vdso64.so
# 00:00:14   OBJCOPY arch/x86/entry/vdso/vdso32.so
# 00:00:14   VDSO2C  arch/x86/entry/vdso/vdso-image-64.c
# 00:00:14   VDSO2C  arch/x86/entry/vdso/vdso-image-32.c
# 00:00:14   CC      arch/x86/entry/vdso/vdso-image-64.o
# 00:00:14   AS      arch/x86/crypto/aesni-intel_asm.o
# 00:00:14   CC      arch/x86/mm/init_64.o
# 00:00:14   CC      arch/x86/entry/vdso/vdso-image-32.o
# 00:00:15   CC      arch/x86/platform/goldfish/goldfish.o
# 00:00:15   CC      arch/x86/crypto/aesni-intel_glue.o
# 00:00:15   AR      arch/x86/entry/vdso/built-in.o
# 00:00:15   CC      arch/x86/events/intel/bts.o
# 00:00:15   AR      arch/x86/entry/built-in.o
# 00:00:15   CC      arch/x86/realmode/init.o
# 00:00:15   CC      arch/x86/kernel/irq_64.o
# 00:00:15   CC      arch/x86/platform/efi/efi_64.o
# 00:00:15   AR      arch/x86/ia32/built-in.o
# 00:00:15   AS      arch/x86/platform/efi/efi_stub_64.o
# 00:00:15   AR      arch/x86/platform/goldfish/built-in.o
# 00:00:15   CC      arch/x86/platform/efi/early_printk.o
# 00:00:15   CC      arch/x86/platform/intel/iosf_mbi.o
# 00:00:15   AS      arch/x86/realmode/rm/header.o
# 00:00:15   AS      arch/x86/realmode/rm/trampoline_64.o
# 00:00:15   AS      arch/x86/realmode/rm/stack.o
# 00:00:15   CC      arch/x86/kernel/dumpstack_64.o
# 00:00:15   AS      arch/x86/realmode/rm/reboot.o
# 00:00:15   CC      arch/x86/events/intel/cqm.o
# 00:00:15   PASYMS  arch/x86/realmode/rm/pasyms.h
# 00:00:15   CC      arch/x86/mm/fault.o
# 00:00:15   LDS     arch/x86/realmode/rm/realmode.lds
# 00:00:15   LD      arch/x86/realmode/rm/realmode.elf
# 00:00:15   CC      arch/x86/crypto/fpu.o
# 00:00:15   RELOCS  arch/x86/realmode/rm/realmode.relocs
# 00:00:15   OBJCOPY arch/x86/realmode/rm/realmode.bin
# 00:00:15   AS      arch/x86/realmode/rmpiggy.o
# 00:00:15   AR      arch/x86/realmode/built-in.o
# 00:00:15   AR      arch/x86/platform/intel-mid/built-in.o
# 00:00:15   AR      arch/x86/platform/intel-quark/built-in.o
# 00:00:15   CC      arch/x86/events/msr.o
# 00:00:15   AR      arch/x86/platform/iris/built-in.o
# 00:00:15   CC      arch/x86/events/intel/ds.o
# 00:00:15   AR      arch/x86/platform/efi/built-in.o
# 00:00:15   AR      arch/x86/platform/intel/built-in.o
# 00:00:15   CC      arch/x86/events/intel/knc.o
# 00:00:16   AR      arch/x86/platform/olpc/built-in.o
# 00:00:16   AR      arch/x86/platform/scx200/built-in.o
# 00:00:16   CC      arch/x86/platform/sfi/sfi.o
# 00:00:16   CC      arch/x86/kernel/time.o
# 00:00:16   AS      arch/x86/crypto/aesni-intel_avx-x86_64.o
# 00:00:16   AR      arch/x86/platform/ts5500/built-in.o
# 00:00:16   AS      arch/x86/crypto/aes_ctrby8_avx-x86_64.o
# 00:00:16   CC      arch/x86/kernel/ioport.o
# 00:00:16   AR      arch/x86/platform/sfi/built-in.o
# 00:00:16   AS      arch/x86/crypto/ghash-clmulni-intel_asm.o
# 00:00:16   AR      arch/x86/platform/uv/built-in.o
# 00:00:16   AR      arch/x86/platform/built-in.o
# 00:00:16   CC      arch/x86/events/intel/lbr.o
# 00:00:16   CC      arch/x86/crypto/ghash-clmulni-intel_glue.o
# 00:00:16   CC      arch/x86/mm/ioremap.o
# 00:00:16   CC      arch/x86/mm/extable.o
# 00:00:16   CC      kernel/fork.o
# 00:00:16   CC      kernel/exec_domain.o
# 00:00:16   CC      kernel/panic.o
# 00:00:17   CC      arch/x86/kernel/dumpstack.o
# 00:00:17   CC      arch/x86/kernel/nmi.o
# 00:00:17   CC      arch/x86/mm/pageattr.o
# 00:00:17   CC      arch/x86/kernel/ldt.o
# 00:00:17   AS      arch/x86/crypto/crc32-pclmul_asm.o
# 00:00:17   CC      arch/x86/events/intel/p4.o
# 00:00:17   CC      arch/x86/crypto/crc32-pclmul_glue.o
# 00:00:17   AS      arch/x86/crypto/sha256-ssse3-asm.o
# 00:00:17   CC      arch/x86/mm/mmap.o
# 00:00:17   AS      arch/x86/crypto/sha256-avx-asm.o
# 00:00:17   AS      arch/x86/crypto/sha256-avx2-asm.o
# 00:00:17   CC      arch/x86/kernel/setup.o
# 00:00:17   CC      arch/x86/kernel/x86_init.o
# 00:00:17   CC      kernel/cpu.o
# 00:00:17   CC      arch/x86/crypto/sha256_ssse3_glue.o
# 00:00:17   CC      arch/x86/events/intel/p6.o
# 00:00:18   AS      arch/x86/crypto/sha256_ni_asm.o
# 00:00:18   AS      arch/x86/crypto/camellia-aesni-avx-asm_64.o
# 00:00:18   CC      kernel/exit.o
# 00:00:18   CC      kernel/softirq.o
# 00:00:18   CC      arch/x86/mm/pat.o
# 00:00:18   CC      kernel/resource.o
# 00:00:18   CC      arch/x86/events/intel/pt.o
# 00:00:18   CC      arch/x86/crypto/camellia_aesni_avx_glue.o
# 00:00:18   AR      certs/built-in.o
# 00:00:18   CC      kernel/sysctl.o
# 00:00:18   CC      arch/x86/kernel/i8259.o
# 00:00:18   CC      arch/x86/kernel/irqinit.o
# 00:00:18   CC      arch/x86/mm/pgtable.o
# 00:00:19   AS      arch/x86/crypto/cast5-avx-x86_64-asm_64.o
# 00:00:19   CC      arch/x86/kernel/jump_label.o
# 00:00:19   CC      arch/x86/crypto/cast5_avx_glue.o
# 00:00:19   CC      arch/x86/events/intel/rapl.o
# 00:00:19   CC      arch/x86/mm/physaddr.o
# 00:00:19   CC      mm/filemap.o
# 00:00:19   CC      mm/mempool.o
# 00:00:19   CC      arch/x86/kernel/irq_work.o
# 00:00:19   CC      arch/x86/kernel/probe_roms.o
# 00:00:19   CC      arch/x86/mm/setup_nx.o
# 00:00:19   CC      arch/x86/mm/tlb.o
# 00:00:19   AS      arch/x86/crypto/twofish-avx-x86_64-asm_64.o
# 00:00:19   CC      arch/x86/events/intel/cstate.o
# 00:00:19   CC      arch/x86/crypto/twofish_avx_glue.o
# 00:00:20   CC      arch/x86/mm/hugetlbpage.o
# 00:00:20   CC      kernel/sysctl_binary.o
# 00:00:20   CC      fs/open.o
# 00:00:20   CC      arch/x86/kernel/sys_x86_64.o
# 00:00:20   CC      arch/x86/kernel/ksysfs.o
# 00:00:20   CC [M]  arch/x86/events/intel/uncore.o
# 00:00:20   CC      mm/oom_kill.o
# 00:00:20   CC      arch/x86/crypto/sha1-mb/sha1_mb.o
# 00:00:20   CC      arch/x86/mm/dump_pagetables.o
# 00:00:20   CC      arch/x86/mm/debug_pagetables.o
# 00:00:20   CC      kernel/capability.o
# 00:00:21   CC      arch/x86/kernel/bootflag.o
# 00:00:21   CC      arch/x86/mm/mpx.o
# 00:00:21   CC      fs/read_write.o
# 00:00:21   CC      ipc/compat.o
# 00:00:21   AS      arch/x86/crypto/sha1-mb/sha1_mb_mgr_flush_avx2.o
# 00:00:21   CC      arch/x86/kernel/e820.o
# 00:00:21   CC      arch/x86/crypto/sha1-mb/sha1_mb_mgr_init_avx2.o
# 00:00:21   CC      mm/maccess.o
# 00:00:21   CC      kernel/ptrace.o
# 00:00:21   AS      arch/x86/crypto/sha1-mb/sha1_mb_mgr_submit_avx2.o
# 00:00:21   CC [M]  arch/x86/events/intel/uncore_nhmex.o
# 00:00:21   AS      arch/x86/crypto/sha1-mb/sha1_x8_avx2.o
# 00:00:21   AR      arch/x86/crypto/sha1-mb/sha1-mb.o
# 00:00:21   AR      arch/x86/crypto/sha1-mb/built-in.o
# 00:00:21   CC      arch/x86/crypto/sha256-mb/sha256_mb.o
# 00:00:21   CC      mm/page_alloc.o
# 00:00:22   AR      arch/x86/mm/built-in.o
# 00:00:22   CC      mm/page-writeback.o
# 00:00:22   CC      ipc/util.o
# 00:00:22   CC      arch/x86/kernel/pci-dma.o
# 00:00:22   CC      kernel/user.o
# 00:00:22   CC [M]  arch/x86/events/intel/uncore_snb.o
# 00:00:22   CC      fs/file_table.o
# 00:00:22   AS      arch/x86/crypto/sha256-mb/sha256_mb_mgr_flush_avx2.o
# 00:00:22   CC      arch/x86/crypto/sha256-mb/sha256_mb_mgr_init_avx2.o
# 00:00:22   AS      arch/x86/crypto/sha256-mb/sha256_mb_mgr_submit_avx2.o
# 00:00:22   AS      arch/x86/crypto/sha256-mb/sha256_x8_avx2.o
# 00:00:22   AR      arch/x86/crypto/sha256-mb/sha256-mb.o
# 00:00:22   AR      arch/x86/crypto/sha256-mb/built-in.o
# 00:00:22   CC      arch/x86/crypto/sha512-mb/sha512_mb.o
# 00:00:22   CC      ipc/msgutil.o
# 00:00:22   CC      kernel/signal.o
# 00:00:22   CC      arch/x86/kernel/quirks.o
# 00:00:23   CC      fs/super.o
# 00:00:23   CC [M]  arch/x86/events/intel/uncore_snbep.o
# 00:00:23   CC      fs/char_dev.o
# 00:00:23   CC      ipc/msg.o
# 00:00:23   AS      arch/x86/crypto/sha512-mb/sha512_mb_mgr_flush_avx2.o
# 00:00:23   CC      arch/x86/crypto/sha512-mb/sha512_mb_mgr_init_avx2.o
# 00:00:23   AS      arch/x86/crypto/sha512-mb/sha512_mb_mgr_submit_avx2.o
# 00:00:23   CC      arch/x86/kernel/topology.o
# 00:00:23   AS      arch/x86/crypto/sha512-mb/sha512_x4_avx2.o
# 00:00:23   AR      arch/x86/crypto/sha512-mb/sha512-mb.o
# 00:00:23   AR      arch/x86/crypto/sha512-mb/built-in.o
# 00:00:23   AS [M]  arch/x86/crypto/blowfish-x86_64-asm_64.o
# 00:00:23   CC [M]  arch/x86/crypto/blowfish_glue.o
# 00:00:23   CC      arch/x86/kernel/kdebugfs.o
# 00:00:23   CC      mm/readahead.o
# 00:00:23   CC      fs/stat.o
# 00:00:23   CC      arch/x86/kernel/alternative.o
# 00:00:23   CC      ipc/sem.o
# 00:00:24   CC      ipc/shm.o
# 00:00:24   AS [M]  arch/x86/crypto/chacha20-ssse3-x86_64.o
# 00:00:24   CC      kernel/sys.o
# 00:00:24   CC [M]  arch/x86/crypto/chacha20_glue.o
# 00:00:24   AR      arch/x86/events/intel/intel-rapl-perf.o
# 00:00:24   AR      arch/x86/events/intel/intel-cstate.o
# 00:00:24   LD [M]  arch/x86/events/intel/intel-uncore.o
# 00:00:24   AR      arch/x86/events/intel/built-in.o
# 00:00:24   AR      arch/x86/events/built-in.o
# 00:00:24   CC      kernel/kmod.o
# 00:00:24   CC      arch/x86/kernel/i8253.o
# 00:00:24   CC      mm/swap.o
# 00:00:24   CC      fs/exec.o
# 00:00:24   CC      arch/x86/kernel/pci-nommu.o
# 00:00:24   AS [M]  arch/x86/crypto/chacha20-avx2-x86_64.o
# 00:00:24   CC      arch/x86/kernel/hw_breakpoint.o
# 00:00:24   AS [M]  arch/x86/crypto/sha512-ssse3-asm.o
# 00:00:25   AS [M]  arch/x86/crypto/sha512-avx-asm.o
# 00:00:25   CC      ipc/syscall.o
# 00:00:25   AS [M]  arch/x86/crypto/sha512-avx2-asm.o
# 00:00:25   CC      ipc/ipc_sysctl.o
# 00:00:25   CC [M]  arch/x86/crypto/sha512_ssse3_glue.o
# 00:00:25   AS [M]  arch/x86/crypto/poly1305-sse2-x86_64.o
# 00:00:25   CC      arch/x86/kernel/tsc.o
# 00:00:25   CC      kernel/workqueue.o
# 00:00:25   AR      ipc/built-in.o
# 00:00:25   CC      kernel/pid.o
# 00:00:25   CC      mm/truncate.o
# 00:00:25   CC      mm/vmscan.o
# 00:00:25   CC      mm/shmem.o
# 00:00:25   CC [M]  arch/x86/crypto/poly1305_glue.o
# 00:00:25   CC      arch/x86/kernel/tsc_msr.o
# 00:00:25   CC      fs/pipe.o
# 00:00:26   CC      arch/x86/kernel/io_delay.o
# 00:00:26   AS [M]  arch/x86/crypto/poly1305-avx2-x86_64.o
# 00:00:26   CC      mm/util.o
# 00:00:26   CC      mm/mmzone.o
# 00:00:26   CC      arch/x86/kernel/rtc.o
# 00:00:26   CC      arch/x86/kernel/pci-iommu_table.o
# 00:00:26   AS [M]  arch/x86/crypto/cast6-avx-x86_64-asm_64.o
# 00:00:26   CC [M]  arch/x86/crypto/cast6_avx_glue.o
# 00:00:26   AS [M]  arch/x86/crypto/serpent-avx-x86_64-asm_64.o
# 00:00:26   CC      kernel/task_work.o
# 00:00:26   CC      fs/namei.o
# 00:00:26   CC      kernel/extable.o
# 00:00:26   CC      arch/x86/kernel/resource.o
# 00:00:26   CC      arch/x86/kernel/process.o
# 00:00:26   CC      arch/x86/kernel/acpi/boot.o
# 00:00:26   CC      mm/vmstat.o
# 00:00:26   CC      security/keys/gc.o
# 00:00:27   CC [M]  arch/x86/crypto/serpent_avx_glue.o
# 00:00:27   AS [M]  arch/x86/crypto/serpent-avx2-asm_64.o
# 00:00:27   CC      kernel/params.o
# 00:00:27   CC      security/commoncap.o
# 00:00:27   CC      security/keys/key.o
# 00:00:27   CC      mm/backing-dev.o
# 00:00:27   CC      mm/mm_init.o
# 00:00:27   CC      arch/x86/kernel/acpi/cstate.o
# 00:00:27   CC [M]  arch/x86/crypto/serpent_avx2_glue.o
# 00:00:27   CC      kernel/kthread.o
# 00:00:28   CC      security/keys/keyring.o
# 00:00:28   AR      arch/x86/kernel/acpi/built-in.o
# 00:00:28   CC      arch/x86/kernel/apic/apic.o
# 00:00:28   CC      crypto/api.o
# 00:00:28   CC      mm/mmu_context.o
# 00:00:28   CC      mm/percpu.o
# 00:00:28   AR      arch/x86/crypto/aes-x86_64.o
# 00:00:28   AR      arch/x86/crypto/camellia-x86_64.o
# 00:00:28   AR      arch/x86/crypto/twofish-x86_64.o
# 00:00:28   AR      arch/x86/crypto/twofish-x86_64-3way.o
# 00:00:28   AR      arch/x86/crypto/aesni-intel.o
# 00:00:28   AR      arch/x86/crypto/ghash-clmulni-intel.o
# 00:00:28   AR      arch/x86/crypto/crc32-pclmul.o
# 00:00:28   AR      arch/x86/crypto/sha256-ssse3.o
# 00:00:28   AR      arch/x86/crypto/camellia-aesni-avx-x86_64.o
# 00:00:28   AR      arch/x86/crypto/cast5-avx-x86_64.o
# 00:00:28   AR      arch/x86/crypto/twofish-avx-x86_64.o
# 00:00:28   LD [M]  arch/x86/crypto/blowfish-x86_64.o
# 00:00:28   LD [M]  arch/x86/crypto/chacha20-x86_64.o
# 00:00:28   LD [M]  arch/x86/crypto/sha512-ssse3.o
# 00:00:28   LD [M]  arch/x86/crypto/poly1305-x86_64.o
# 00:00:28   LD [M]  arch/x86/crypto/cast6-avx-x86_64.o
# 00:00:28   LD [M]  arch/x86/crypto/serpent-avx-x86_64.o
# 00:00:28   LD [M]  arch/x86/crypto/serpent-avx2.o
# 00:00:28   AR      arch/x86/crypto/built-in.o
# 00:00:28   CC      mm/slab_common.o
# 00:00:28   CC      fs/fcntl.o
# 00:00:28   CC      kernel/sys_ni.o
# 00:00:28   CC      kernel/nsproxy.o
# 00:00:28   CC      arch/x86/kernel/cpu/intel_cacheinfo.o
# 00:00:28   CC      security/keys/keyctl.o
# 00:00:28   CC      crypto/cipher.o
# 00:00:29   CC      arch/x86/kernel/apic/apic_noop.o
# 00:00:29   CC      arch/x86/kernel/apic/ipi.o
# 00:00:29   CC      mm/compaction.o
# 00:00:29   CC      fs/ioctl.o
# 00:00:29   CC      kernel/notifier.o
# 00:00:29   CC      arch/x86/kernel/cpu/scattered.o
# 00:00:29   AR      block/built-in.o
# 00:00:29   CC      arch/x86/kernel/cpu/topology.o
# 00:00:29   CC      crypto/compress.o
# 00:00:29   CC      security/keys/permission.o
# 00:00:29   CC      arch/x86/kernel/apic/vector.o
# 00:00:29   CC      arch/x86/kernel/apic/hw_nmi.o
# 00:00:29   CC      arch/x86/kernel/cpu/common.o
# 00:00:29   CC      kernel/ksysfs.o
# 00:00:30   CC      mm/vmacache.o
# 00:00:30   CC      fs/readdir.o
# 00:00:30   CC      crypto/memneq.o
# 00:00:30   CC      security/keys/process_keys.o
# 00:00:30   CC      arch/x86/kernel/cpu/rdrand.o
# 00:00:30   CC      arch/x86/kernel/apic/io_apic.o
# 00:00:30   CC      security/min_addr.o
# 00:00:30   CC      kernel/cred.o
# 00:00:30   CC      mm/swap_slots.o
# 00:00:30   CC      crypto/crypto_wq.o
# 00:00:30   CC      arch/x86/kernel/cpu/match.o
# 00:00:30   CC      fs/select.o
# 00:00:30   CC      security/keys/request_key.o
# 00:00:30   AR      drivers/accessibility/braille/built-in.o
# 00:00:30   AR      drivers/accessibility/built-in.o
# 00:00:30   CC      drivers/acpi/tables.o
# 00:00:30   CC      mm/interval_tree.o
# 00:00:31   CC      kernel/reboot.o
# 00:00:31   CC      arch/x86/kernel/cpu/bugs.o
# 00:00:31   CC      crypto/algapi.o
# 00:00:31   CC      security/keys/request_key_auth.o
# 00:00:31   CC      drivers/acpi/blacklist.o
# 00:00:31   CC      arch/x86/kernel/cpu/proc.o
# 00:00:31   CC      mm/list_lru.o
# 00:00:31   CC      arch/x86/kernel/apic/apic_flat_64.o
# 00:00:31   CC      kernel/async.o
# 00:00:31   CC      security/keys/user_defined.o
# 00:00:31   MKCAP   arch/x86/kernel/cpu/capflags.c
# 00:00:32   CC      drivers/acpi/osi.o
# 00:00:32   CC      kernel/range.o
# 00:00:32   CC      fs/dcache.o
# 00:00:32   CC      arch/x86/kernel/apic/probe_64.o
# 00:00:32   CC      security/keys/compat.o
# 00:00:32   CC      kernel/smpboot.o
# 00:00:32   CC      mm/workingset.o
# 00:00:32   CC      crypto/scatterwalk.o
# 00:00:32   CC      drivers/acpi/osl.o
# 00:00:32   AR      arch/x86/kernel/apic/built-in.o
# 00:00:32   CC      security/keys/compat_dh.o
# 00:00:32   CC      kernel/ucount.o
# 00:00:32   CC      mm/debug.o
# 00:00:32   CC      crypto/proc.o
# 00:00:32   CC      security/keys/proc.o
# 00:00:32   CC      mm/gup.o
# 00:00:32   CC      kernel/cgroup/cgroup.o
# 00:00:33   CC      security/keys/sysctl.o
# 00:00:33   CC      crypto/aead.o
# 00:00:33   CC      drivers/acpi/utils.o
# 00:00:33   CC      crypto/ablkcipher.o
# 00:00:33   CC      fs/inode.o
# 00:00:33   CC      security/keys/dh.o
# 00:00:33   CC      mm/highmem.o
# 00:00:34   CC      drivers/acpi/reboot.o
# 00:00:34   CC      mm/memory.o
# 00:00:34   CC      crypto/blkcipher.o
# 00:00:34   CC      security/keys/encrypted-keys/encrypted.o
# 00:00:34   CC      security/keys/encrypted-keys/ecryptfs_format.o
# 00:00:34   CC      fs/attr.o
# 00:00:34   CC      drivers/acpi/nvs.o
# 00:00:34   CC      security/inode.o
# 00:00:34   CC      arch/x86/kernel/cpu/powerflags.o
# 00:00:34   CC      crypto/skcipher.o
# 00:00:34   CC      kernel/cgroup/namespace.o
# 00:00:34   CC      arch/x86/kernel/cpu/intel.o
# 00:00:34   AR      security/keys/encrypted-keys/encrypted-keys.o
# 00:00:34   AR      security/keys/encrypted-keys/built-in.o
# 00:00:34   AR      security/keys/built-in.o
# 00:00:34   CC      crypto/seqiv.o
# 00:00:35   CC      drivers/acpi/wakeup.o
# 00:00:35   CC      fs/bad_inode.o
# 00:00:35   AR      security/built-in.o
# 00:00:35   CC      crypto/ahash.o
# 00:00:35   CC      kernel/cgroup/cgroup-v1.o
# 00:00:35   CC      fs/file.o
# 00:00:35   CC      arch/x86/kernel/cpu/amd.o
# 00:00:35   CC      drivers/acpi/sleep.o
# 00:00:35   CC      sound/sound_core.o
# 00:00:35   CC      mm/mincore.o
# 00:00:35   CC      sound/arm/pxa2xx-pcm-lib.o
# 00:00:36   CC      arch/x86/kernel/cpu/centaur.o
# 00:00:36   CC      crypto/shash.o
# 00:00:36   CC      crypto/akcipher.o
# 00:00:36   CC      kernel/cgroup/freezer.o
# 00:00:36   CC      drivers/acpi/device_sysfs.o
# 00:00:36   CC      fs/filesystems.o
# 00:00:36   CC      arch/x86/kernel/cpu/mcheck/mce.o
# 00:00:36   CC      mm/mlock.o
# 00:00:36   AR      sound/arm/snd-pxa2xx-lib.o
# 00:00:36   AR      sound/arm/built-in.o
# 00:00:36   AR      sound/atmel/built-in.o
# 00:00:36   CC      kernel/cgroup/debug.o
# 00:00:36   CC      sound/core/sound.o
# 00:00:36   CC      sound/core/init.o
# 00:00:36   CC      crypto/kpp.o
# 00:00:36   CC      drivers/acpi/device_pm.o
# 00:00:36   CC      fs/namespace.o
# 00:00:37   CC      crypto/dh.o
# 00:00:37   AR      kernel/cgroup/built-in.o
# 00:00:37   CC      kernel/debug/debug_core.o
# 00:00:37   CC      sound/core/memory.o
# 00:00:37   CC      mm/mmap.o
# 00:00:37   CC      sound/core/control.o
# 00:00:37   CC      arch/x86/kernel/cpu/mcheck/mce-severity.o
# 00:00:37   CC      crypto/dh_helper.o
# 00:00:37   ASN.1   crypto/rsapubkey-asn1.c
# 00:00:37   CC      sound/core/misc.o
# 00:00:37   CC      drivers/acpi/bus.o
# 00:00:37   CC      arch/x86/kernel/cpu/mcheck/mce-genpool.o
# 00:00:37   CC      kernel/debug/gdbstub.o
# 00:00:37   ASN.1   crypto/rsaprivkey-asn1.c
# 00:00:37   CC      crypto/rsa.o
# 00:00:38   CC      crypto/rsa_helper.o
# 00:00:38   CC      fs/seq_file.o
# 00:00:38   CC      arch/x86/kernel/cpu/mcheck/mce_intel.o
# 00:00:38   CC      arch/x86/kernel/cpu/mcheck/threshold.o
# 00:00:38   CC      sound/core/device.o
# 00:00:38   CC      crypto/rsa-pkcs1pad.o
# 00:00:38   CC      drivers/acpi/glue.o
# 00:00:38   CC      crypto/acompress.o
# 00:00:38   CC      kernel/debug/kdb/kdb_io.o
# 00:00:38   CC      arch/x86/kernel/cpu/mcheck/mce-inject.o
# 00:00:38   CC      mm/mprotect.o
# 00:00:38   CC      sound/core/vmaster.o
# 00:00:38   CC      fs/xattr.o
# 00:00:39   CC      kernel/debug/kdb/kdb_main.o
# 00:00:39   CC      drivers/acpi/scan.o
# 00:00:39   CC      fs/libfs.o
# 00:00:39   CC      crypto/scompress.o
# 00:00:39   CC      sound/core/ctljack.o
# 00:00:39   CC      arch/x86/kernel/cpu/mcheck/therm_throt.o
# 00:00:39   CC      mm/mremap.o
# 00:00:39   CC      sound/core/jack.o
# 00:00:39   CC      arch/x86/kernel/cpu/mcheck/dev-mcelog.o
# 00:00:39   CC      crypto/algboss.o
# 00:00:39   CC      fs/fs-writeback.o
# 00:00:39   CC      mm/msync.o
# 00:00:40   CC      sound/core/hwdep.o
# 00:00:40   CC      drivers/acpi/resource.o
# 00:00:40   AR      arch/x86/kernel/cpu/mcheck/built-in.o
# 00:00:40   CC      arch/x86/kernel/cpu/perfctr-watchdog.o
# 00:00:40   CC      kernel/debug/kdb/kdb_support.o
# 00:00:40   CC      kernel/debug/kdb/kdb_bt.o
# 00:00:40   CC      mm/page_vma_mapped.o
# 00:00:40   CC      sound/core/timer.o
# 00:00:40   CC      crypto/testmgr.o
# 00:00:40   CC      arch/x86/kernel/cpu/capflags.o
# 00:00:40   AR      arch/x86/kernel/cpu/built-in.o
# 00:00:40   CC      mm/pagewalk.o
# 00:00:40   CC      arch/x86/kernel/fpu/init.o
# 00:00:40   CC      drivers/acpi/acpi_processor.o
# 00:00:40   GENKDB  kernel/debug/kdb/gen-kdb_cmds.c
# 00:00:40   CC      kernel/debug/kdb/kdb_bp.o
# 00:00:40   CC      fs/pnode.o
# 00:00:41   CC      kernel/debug/kdb/kdb_debugger.o
# 00:00:41   CC      mm/pgtable-generic.o
# 00:00:41   CC      arch/x86/kernel/fpu/bugs.o
# 00:00:41   CC      kernel/events/core.o
# 00:00:41   CC      fs/splice.o
# 00:00:41   CC      drivers/acpi/processor_core.o
# 00:00:41   CC      kernel/debug/kdb/gen-kdb_cmds.o
# 00:00:41   AR      kernel/debug/kdb/built-in.o
# 00:00:41   AR      kernel/debug/built-in.o
# 00:00:41   CC      kernel/events/ring_buffer.o
# 00:00:41   CC      sound/core/pcm.o
# 00:00:41   CC      arch/x86/kernel/fpu/core.o
# 00:00:41   CC      mm/rmap.o
# 00:00:41   CC      drivers/acpi/processor_pdc.o
# 00:00:42   CC      crypto/hmac.o
# 00:00:42   CC      sound/core/pcm_native.o
# 00:00:42   CC      drivers/acpi/ec.o
# 00:00:42   CC      arch/x86/kernel/fpu/regset.o
# 00:00:42   CC      arch/x86/kernel/fpu/signal.o
# 00:00:42   CC      fs/sync.o
# 00:00:42   CC      mm/vmalloc.o
# 00:00:42   CC      drivers/acpi/dock.o
# 00:00:42   CC      crypto/vmac.o
# 00:00:42   CC      arch/x86/kernel/fpu/xstate.o
# 00:00:43   CC      fs/utimes.o
# 00:00:43   CC      mm/process_vm_access.o
# 00:00:43   CC      drivers/acpi/pci_root.o
# 00:00:43   AR      arch/x86/kernel/fpu/built-in.o
# 00:00:43   CC      arch/x86/kernel/kprobes/core.o
# 00:00:43   CC      crypto/crypto_null.o
# 00:00:43   CC      fs/stack.o
# 00:00:43   CC      crypto/rmd128.o
# 00:00:43   CC      mm/init-mm.o
# 00:00:43   CC      sound/core/pcm_lib.o
# 00:00:44   CC      fs/fs_struct.o
# 00:00:44   CC      drivers/acpi/pci_link.o
# 00:00:44   CC      mm/nobootmem.o
# 00:00:44   CC      mm/fadvise.o
# 00:00:44   CC      arch/x86/kernel/kprobes/opt.o
# 00:00:44   CC      kernel/events/callchain.o
# 00:00:44   CC      fs/statfs.o
# 00:00:44   CC      crypto/sha1_generic.o
# 00:00:44   CC      crypto/sha256_generic.o
# 00:00:44   CC      drivers/acpi/pci_irq.o
# 00:00:44   CC      mm/madvise.o
# 00:00:44   AR      arch/x86/kernel/kprobes/built-in.o
# 00:00:44   CC      sound/core/pcm_misc.o
# 00:00:44   CC      arch/x86/kernel/ptrace.o
# 00:00:45   CC      kernel/events/hw_breakpoint.o
# 00:00:45   CC      mm/memblock.o
# 00:00:45   CC      fs/fs_pin.o
# 00:00:45   CC      drivers/acpi/acpi_lpss.o
# 00:00:45   CC      fs/nsfs.o
# 00:00:45   CC      sound/core/pcm_memory.o
# 00:00:45   CC      crypto/sha512_generic.o
# 00:00:45   AR      kernel/events/built-in.o
# 00:00:45   CC      kernel/gcov/base.o
# 00:00:45   CC      fs/no-block.o
# 00:00:45   CC      mm/dmapool.o
# 00:00:45   CC      fs/proc_namespace.o
# 00:00:45   CC      arch/x86/kernel/tls.o
# 00:00:45   CC      kernel/gcov/fs.o
# 00:00:46   CC      sound/core/memalloc.o
# 00:00:46   CC      mm/hugetlb.o
# 00:00:46   CC      drivers/acpi/acpi_apd.o
# 00:00:46   CC      crypto/tgr192.o
# 00:00:46   CC      sound/drivers/serial-u16550.o
# 00:00:46   CC      fs/autofs4/init.o
# 00:00:46   CC      kernel/gcov/gcc_4_7.o
# 00:00:46   CC      drivers/acpi/acpi_platform.o
# 00:00:46   CC      arch/x86/kernel/step.o
# 00:00:46   CC      sound/core/pcm_timer.o
# 00:00:46   CC      crypto/gf128mul.o
# 00:00:46   AR      kernel/gcov/built-in.o
# 00:00:46   CC      kernel/irq/irqdesc.o
# 00:00:47   CC      sound/core/sgbuf.o
# 00:00:47   CC      arch/x86/kernel/stacktrace.o
# 00:00:47   CC      drivers/acpi/acpi_pnp.o
# 00:00:47   CC      crypto/ecb.o
# 00:00:47   CC      fs/autofs4/inode.o
# 00:00:47   CC      sound/drivers/mpu401/mpu401_uart.o
# 00:00:47   CC      kernel/irq/handle.o
# 00:00:47   CC      sound/core/pcm_drm_eld.o
# 00:00:47   CC      drivers/acpi/power.o
# 00:00:47   CC      arch/x86/kernel/reboot.o
# 00:00:47   CC      mm/sparse.o
# 00:00:47   CC      crypto/cbc.o
# 00:00:47   CC      fs/autofs4/root.o
# 00:00:47   CC      kernel/irq/manage.o
# 00:00:47   AR      sound/drivers/mpu401/snd-mpu401-uart.o
# 00:00:47   AR      sound/drivers/mpu401/built-in.o
# 00:00:47   CC      sound/drivers/opl3/opl3_lib.o
# 00:00:48   CC      sound/core/pcm_iec958.o
# 00:00:48   CC      drivers/acpi/event.o
# 00:00:48   CC      mm/sparse-vmemmap.o
# 00:00:48   CC      arch/x86/kernel/msr.o
# 00:00:48   CC      fs/autofs4/symlink.o
# 00:00:48   CC      crypto/pcbc.o
# 00:00:48   CC      sound/drivers/opl3/opl3_synth.o
# 00:00:48   CC      sound/core/pcm_dmaengine.o
# 00:00:48   CC      arch/x86/kernel/early-quirks.o
# 00:00:48   CC      kernel/irq/spurious.o
# 00:00:48   CC      fs/autofs4/waitq.o
# 00:00:48   CC      mm/slob.o
# 00:00:48   CC      drivers/acpi/sysfs.o
# 00:00:49   CC      crypto/lrw.o
# 00:00:49   CC [M]  sound/drivers/opl3/opl3_seq.o
# 00:00:49   CC      kernel/irq/resend.o
# 00:00:49   CC      fs/autofs4/expire.o
# 00:00:49   CC      sound/core/seq_device.o
# 00:00:49   CC      arch/x86/kernel/tsc_sync.o
# 00:00:49   CC      drivers/acpi/property.o
# 00:00:49   CC [M]  sound/drivers/opl3/opl3_midi.o
# 00:00:49   CC      mm/memtest.o
# 00:00:49   CC      kernel/irq/chip.o
# 00:00:49   CC      sound/core/rawmidi.o
# 00:00:49   CC      fs/autofs4/dev-ioctl.o
# 00:00:49   CC      arch/x86/kernel/mpparse.o
# 00:00:49   CC      crypto/xts.o
# 00:00:49   CC      mm/migrate.o
# 00:00:50   CC [M]  sound/drivers/opl3/opl3_drums.o
# 00:00:50   CC      drivers/acpi/acpi_cmos_rtc.o
# 00:00:50   CC      kernel/irq/dummychip.o
# 00:00:50   AR      fs/autofs4/autofs4.o
# 00:00:50   AR      fs/autofs4/built-in.o
# 00:00:50   CC      fs/configfs/inode.o
# 00:00:50   AR      sound/drivers/opl3/snd-opl3-lib.o
# 00:00:50   LD [M]  sound/drivers/opl3/snd-opl3-synth.o
# 00:00:50   AR      sound/drivers/opl3/built-in.o
# 00:00:50   AR      sound/drivers/opl4/built-in.o
# 00:00:50   AR      sound/drivers/pcsp/built-in.o
# 00:00:50   AR      sound/drivers/vx/built-in.o
# 00:00:50   CC [M]  sound/drivers/vx/vx_core.o
# 00:00:50   CC      arch/x86/kernel/trace_clock.o
# 00:00:50   CC      sound/core/compress_offload.o
# 00:00:50   CC      crypto/ctr.o
# 00:00:50   CC      drivers/acpi/x86/utils.o
# 00:00:50   CC      arch/x86/kernel/machine_kexec_64.o
# 00:00:50   CC      kernel/irq/devres.o
# 00:00:50   CC      mm/page_counter.o
# 00:00:50   CC      fs/configfs/file.o
# 00:00:50   CC      drivers/acpi/debugfs.o
# 00:00:51   CC      kernel/irq/generic-chip.o
# 00:00:51   CC [M]  sound/drivers/vx/vx_hwdep.o
# 00:00:51   CC      crypto/ccm.o
# 00:00:51   CC      mm/memcontrol.o
# 00:00:51   AR      sound/core/seq/built-in.o
# 00:00:51   AS      arch/x86/kernel/relocate_kernel_64.o
# 00:00:51   CC [M]  sound/core/seq/seq.o
# 00:00:51   CC      fs/configfs/dir.o
# 00:00:51   CC      arch/x86/kernel/crash.o
# 00:00:51   CC      drivers/acpi/cm_sbs.o
# 00:00:51   CC      kernel/irq/autoprobe.o
# 00:00:51   CC [M]  sound/drivers/vx/vx_pcm.o
# 00:00:51   CC [M]  sound/core/seq/seq_lock.o
# 00:00:51   CC      drivers/acpi/acpi_lpat.o
# 00:00:51   CC      arch/x86/kernel/crash_dump_64.o
# 00:00:51   CC      kernel/irq/irqdomain.o
# 00:00:51   CC      crypto/chacha20poly1305.o
# 00:00:52   CC      fs/configfs/symlink.o
# 00:00:52   CC [M]  sound/core/seq/seq_clientmgr.o
# 00:00:52   CC      drivers/acpi/acpi_watchdog.o
# 00:00:52   CC [M]  sound/drivers/vx/vx_mixer.o
# 00:00:52   CC      arch/x86/kernel/module.o
# 00:00:52   CC      fs/configfs/mount.o
# 00:00:52   CC      kernel/irq/proc.o
# 00:00:52   CC      crypto/cryptd.o
# 00:00:52   CC      drivers/acpi/acpica/dsargs.o
# 00:00:52   CC      arch/x86/kernel/doublefault.o
# 00:00:52   CC [M]  sound/core/seq/seq_memory.o
# 00:00:52   CC      fs/configfs/item.o
# 00:00:53   CC      drivers/acpi/acpica/dscontrol.o
# 00:00:53   CC [M]  sound/drivers/vx/vx_cmd.o
# 00:00:53   AR      kernel/irq/built-in.o
# 00:00:53   AR      kernel/livepatch/built-in.o
# 00:00:53   CC      kernel/locking/mutex.o
# 00:00:53   CC      mm/vmpressure.o
# 00:00:53   AR      fs/configfs/configfs.o
# 00:00:53   AR      fs/configfs/built-in.o
# 00:00:53   CC      fs/debugfs/inode.o
# 00:00:53   CC      drivers/acpi/acpica/dsdebug.o
# 00:00:53   CC      arch/x86/kernel/kgdb.o
# 00:00:53   CC [M]  sound/core/seq/seq_queue.o
# 00:00:53   CC [M]  sound/drivers/vx/vx_uer.o
# 00:00:53   CC      kernel/locking/semaphore.o
# 00:00:53   CC      crypto/mcryptd.o
# 00:00:53   CC      drivers/acpi/acpica/dsfield.o
# 00:00:53   CC      mm/rodata_test.o
# 00:00:53   CC      fs/debugfs/file.o
# 00:00:54   CC [M]  sound/core/seq/seq_fifo.o
# 00:00:54   CC      mm/cleancache.o
# 00:00:54   CC      arch/x86/kernel/early_printk.o
# 00:00:54   CC      kernel/locking/rwsem.o
# 00:00:54   CC      drivers/acpi/acpica/dsinit.o
# 00:00:54   LD [M]  sound/drivers/vx/snd-vx-lib.o
# 00:00:54   CC [M]  sound/drivers/dummy.o
# 00:00:54   CC      kernel/locking/percpu-rwsem.o
# 00:00:54   CC      crypto/blowfish_generic.o
# 00:00:54   CC      drivers/acpi/acpica/dsmethod.o
# 00:00:54   CC [M]  sound/core/seq/seq_prioq.o
# 00:00:54   CC      mm/page_isolation.o
# 00:00:54   CC      kernel/locking/mutex-debug.o
# 00:00:54   AR      fs/debugfs/debugfs.o
# 00:00:54   CC      arch/x86/kernel/hpet.o
# 00:00:54   AR      fs/debugfs/built-in.o
# 00:00:54   AR      fs/devpts/built-in.o
# 00:00:54   AR      fs/efivarfs/built-in.o
# 00:00:54   CC [M]  fs/efivarfs/inode.o
# 00:00:54   CC      drivers/acpi/acpica/dsmthdat.o
# 00:00:54   CC [M]  sound/drivers/aloop.o
# 00:00:54   CC      crypto/blowfish_common.o
# 00:00:54   CC [M]  sound/core/seq/seq_timer.o
# 00:00:54   CC      kernel/locking/rtmutex.o
# 00:00:55   CC      mm/zpool.o
# 00:00:55   CC      drivers/acpi/acpica/dsobject.o
# 00:00:55   CC [M]  fs/efivarfs/file.o
# 00:00:55   CC      kernel/locking/rtmutex-debug.o
# 00:00:55   CC [M]  sound/core/seq/seq_system.o
# 00:00:55   CC      arch/x86/kernel/amd_nb.o
# 00:00:55   CC      crypto/twofish_common.o
# 00:00:55   CC [M]  sound/drivers/virmidi.o
# 00:00:55   CC      drivers/acpi/acpica/dsopcode.o
# 00:00:55   CC      mm/early_ioremap.o
# 00:00:55   CC [M]  fs/efivarfs/super.o
# 00:00:55   CC [M]  sound/core/seq/seq_ports.o
# 00:00:55   CC      drivers/acpi/acpica/dsutils.o
# 00:00:56   CC      crypto/serpent_generic.o
# 00:00:56   CC [M]  sound/drivers/mtpav.o
# 00:00:56   CC      kernel/locking/spinlock.o
# 00:00:56   CC      arch/x86/kernel/nmi_selftest.o
# 00:00:56   CC      mm/cma.o
# 00:00:56   LD [M]  fs/efivarfs/efivarfs.o
# 00:00:56   AR      fs/exofs/built-in.o
# 00:00:56   CC      arch/x86/kernel/pcspeaker.o
# 00:00:56   CC      fs/exportfs/expfs.o
# 00:00:56   CC      kernel/locking/spinlock_debug.o
# 00:00:56   CC      drivers/acpi/acpica/dswexec.o
# 00:00:56   CC [M]  sound/core/seq/seq_dummy.o
# 00:00:56   AR      sound/drivers/snd-serial-u16550.o
# 00:00:56   LD [M]  sound/drivers/snd-dummy.o
# 00:00:56   LD [M]  sound/drivers/snd-aloop.o
# 00:00:56   CC      mm/balloon_compaction.o
# 00:00:56   LD [M]  sound/drivers/snd-virmidi.o
# 00:00:56   CC      arch/x86/kernel/check.o
# 00:00:56   LD [M]  sound/drivers/snd-mtpav.o
# 00:00:56   AR      sound/drivers/built-in.o
# 00:00:56   CC      kernel/locking/rwsem-xadd.o
# 00:00:56   CC      arch/x86/kernel/pci-swiotlb.o
# 00:00:56   CC      drivers/acpi/acpica/dswload.o
# 00:00:56   AR      fs/exportfs/exportfs.o
# 00:00:56   AR      fs/exportfs/built-in.o
# 00:00:56   AR      fs/fscache/built-in.o
# 00:00:56   CC [M]  fs/fscache/cache.o
# 00:00:56   CC [M]  sound/core/seq/seq_midi.o
# 00:00:56   CC      crypto/aes_generic.o
# 00:00:56   CC [M]  kernel/locking/locktorture.o
# 00:00:57   CC      crypto/camellia_generic.o
# 00:00:57   CC      drivers/acpi/acpica/dswload2.o
# 00:00:57   CC      mm/cma_debug.o
# 00:00:57   CC      arch/x86/kernel/sysfb.o
# 00:00:57   CC [M]  sound/core/seq/seq_midi_emul.o
# 00:00:57   CC [M]  fs/fscache/cookie.o
# 00:00:57   CC      drivers/acpi/acpica/dswscope.o
# 00:00:57   CC      mm/userfaultfd.o
# 00:00:57   AR      kernel/locking/built-in.o
# 00:00:57   CC      kernel/power/qos.o
# 00:00:57   CC      kernel/power/main.o
# 00:00:57   CC      arch/x86/kernel/sysfb_efi.o
# 00:00:57   CC      drivers/acpi/acpica/dswstate.o
# 00:00:57   CC [M]  sound/core/seq/seq_midi_event.o
# 00:00:57   CC      crypto/cast_common.o
# 00:00:58   CC [M]  fs/fscache/fsdef.o
# 00:00:58   CC      drivers/acpi/acpica/evevent.o
# 00:00:58   CC      crypto/cast5_generic.o
# 00:00:58   CC      crypto/arc4.o
# 00:00:58   CC      kernel/power/process.o
# 00:00:58   CC      mm/frame_vector.o
# 00:00:58   CC [M]  sound/core/seq/seq_virmidi.o
# 00:00:58   CC      arch/x86/kernel/perf_regs.o
# 00:00:58   CC      drivers/acpi/acpica/evgpe.o
# 00:00:58   CC [M]  fs/fscache/main.o
# 00:00:58   CC      drivers/acpi/acpica/evgpeblk.o
# 00:00:58   CC      crypto/khazad.o
# 00:00:58   CC      mm/percpu-stats.o
# 00:00:58   CC      crypto/anubis.o
# 00:00:58   LD [M]  sound/core/seq/snd-seq.o
# 00:00:58   CC      arch/x86/kernel/unwind_frame.o
# 00:00:58   LD [M]  sound/core/seq/snd-seq-dummy.o
# 00:00:58   LD [M]  sound/core/seq/snd-seq-midi.o
# 00:00:58   LD [M]  sound/core/seq/snd-seq-midi-emul.o
# 00:00:58   LD [M]  sound/core/seq/snd-seq-midi-event.o
# 00:00:58   LD [M]  sound/core/seq/snd-seq-virmidi.o
# 00:00:58   AR      sound/core/snd.o
# 00:00:58   AR      sound/core/snd-hwdep.o
# 00:00:58   AR      sound/core/snd-timer.o
# 00:00:58   AR      sound/core/snd-pcm.o
# 00:00:58   AR      sound/core/snd-pcm-dmaengine.o
# 00:00:58   AR      sound/core/snd-seq-device.o
# 00:00:58   AR      sound/core/snd-rawmidi.o
# 00:00:58   AR      sound/core/snd-compress.o
# 00:00:58   CC      kernel/power/poweroff.o
# 00:00:58   AR      sound/core/built-in.o
# 00:00:58   AR      sound/firewire/built-in.o
# 00:00:58   CC [M]  sound/firewire/lib.o
# 00:00:59   CC      drivers/acpi/acpica/evgpeinit.o
# 00:00:59   CC [M]  fs/fscache/netfs.o
# 00:00:59   AR      kernel/power/built-in.o
# 00:00:59   CC      kernel/printk/printk.o
# 00:00:59   CC [M]  mm/zsmalloc.o
# 00:00:59   CC [M]  mm/z3fold.o
# 00:00:59   CC      drivers/acpi/acpica/evgpeutil.o
# 00:00:59   CC      arch/x86/kernel/amd_gart_64.o
# 00:00:59   CC      crypto/chacha20_generic.o
# 00:00:59   CC [M]  sound/firewire/iso-resources.o
# 00:00:59   CC [M]  fs/fscache/object.o
# 00:00:59   CC      drivers/acpi/acpica/evglock.o
# 00:00:59   CC      drivers/acpi/acpica/evhandler.o
# 00:00:59   CC [M]  sound/firewire/packets-buffer.o
# 00:00:59   CC      crypto/poly1305_generic.o
# 00:01:00   CC      crypto/deflate.o
# 00:01:00   AR      mm/built-in.o
# 00:01:00   CC      crypto/crct10dif_common.o
# 00:01:00   CC      arch/x86/kernel/aperture_64.o
# 00:01:00   CC [M]  fs/fscache/operation.o
# 00:01:00   CC      drivers/acpi/acpica/evmisc.o
# 00:01:00   CC      kernel/printk/printk_safe.o
# 00:01:00   CC      drivers/acpi/acpica/evregion.o
# 00:01:00   CC [M]  sound/firewire/fcp.o
# 00:01:00   AR      kernel/printk/built-in.o
# 00:01:00   CC      kernel/rcu/update.o
# 00:01:00   CC      kernel/sched/core.o
# 00:01:00   CC      kernel/time/time.o
# 00:01:00   CC      crypto/crct10dif_generic.o
# 00:01:00   CC      drivers/acpi/acpica/evrgnini.o
# 00:01:00   CC      arch/x86/kernel/mmconf-fam10h_64.o
# 00:01:00   CC [M]  fs/fscache/page.o
# 00:01:00   CC      kernel/rcu/sync.o
# 00:01:01   CC      drivers/acpi/acpica/evsci.o
# 00:01:01   CC [M]  sound/firewire/cmp.o
# 00:01:01   CC      crypto/authenc.o
# 00:01:01   CC      kernel/rcu/srcutiny.o
# 00:01:01   CC      kernel/time/timer.o
# 00:01:01   CC      arch/x86/kernel/vsmp_64.o
# 00:01:01   CC      drivers/acpi/acpica/evxface.o
# 00:01:01   CC      kernel/rcu/tiny.o
# 00:01:01   CC [M]  fs/fscache/proc.o
# 00:01:01   AS      arch/x86/kernel/head_64.o
# 00:01:01   CC [M]  sound/firewire/amdtp-stream.o
# 00:01:01   CC      arch/x86/kernel/head64.o
# 00:01:01   CC      drivers/acpi/acpica/evxfevnt.o
# 00:01:01   AR      kernel/rcu/built-in.o
# 00:01:01   CC      crypto/authencesn.o
# 00:01:02   CC      kernel/trace/trace_clock.o
# 00:01:02   CC [M]  fs/fscache/object-list.o
# 00:01:02   CC      drivers/acpi/acpica/evxfgpe.o
# 00:01:02   CC      kernel/time/hrtimer.o
# 00:01:02   CC      kernel/sched/loadavg.o
# 00:01:02   CC      arch/x86/kernel/ebda.o
# 00:01:02   CC      kernel/trace/ring_buffer.o
# 00:01:02   CC [M]  sound/firewire/amdtp-am824.o
# 00:01:02   CC      drivers/acpi/acpica/evxfregn.o
# 00:01:02   CC      kernel/sched/clock.o
# 00:01:02   LD [M]  fs/fscache/fscache.o
# 00:01:02   CC      fs/fuse/dev.o
# 00:01:02   CC      arch/x86/kernel/platform-quirks.o
# 00:01:02   CC      crypto/lzo.o
# 00:01:02   LDS     arch/x86/kernel/vmlinux.lds
# 00:01:02   CC      drivers/acpi/acpica/exconcat.o
# 00:01:02   AR      arch/x86/kernel/built-in.o
# 00:01:02   AR      arch/x86/built-in.o
# 00:01:02   CC      kernel/time/timekeeping.o
# 00:01:02   CC      kernel/time/ntp.o
# 00:01:02   AR      sound/firewire/bebob/built-in.o
# 00:01:02   CC      kernel/sched/cputime.o
# 00:01:02   CC [M]  sound/firewire/bebob/bebob_command.o
# 00:01:03   CC      drivers/acpi/acpica/exconfig.o
# 00:01:03   CC      crypto/lz4.o
# 00:01:03   CC      kernel/sched/idle_task.o
# 00:01:03   CC      drivers/acpi/acpica/exconvrt.o
# 00:01:03   CC      crypto/842.o
# 00:01:03   CC      crypto/rng.o
# 00:01:03   CC [M]  sound/firewire/bebob/bebob_stream.o
# 00:01:03   AR      kernel/trace/built-in.o
# 00:01:03   CC      crypto/drbg.o
# 00:01:03   CC      kernel/time/clocksource.o
# 00:01:03   CC      drivers/acpi/acpica/excreate.o
# 00:01:03   CC      fs/fuse/dir.o
# 00:01:03   CC      drivers/acpi/acpica/exdebug.o
# 00:01:03   CC      kernel/sched/fair.o
# 00:01:04   CC      kernel/sched/rt.o
# 00:01:04   CC      kernel/sched/deadline.o
# 00:01:04   CC      drivers/acpi/acpica/exdump.o
# 00:01:04   CC [M]  sound/firewire/bebob/bebob_proc.o
# 00:01:04   CC      kernel/time/jiffies.o
# 00:01:04   CC      crypto/jitterentropy.o
# 00:01:04   CC      crypto/jitterentropy-kcapi.o
# 00:01:04   CC      kernel/time/timer_list.o
# 00:01:04   CC      drivers/acpi/acpica/exfield.o
# 00:01:04   CC      kernel/time/timeconv.o
# 00:01:04   CC      fs/fuse/file.o
# 00:01:04   CC      fs/hugetlbfs/inode.o
# 00:01:04   CC      kernel/sched/wait.o
# 00:01:04   CC [M]  sound/firewire/bebob/bebob_midi.o
# 00:01:04   CC      drivers/acpi/acpica/exfldio.o
# 00:01:05   CC      drivers/acpi/acpica/exmisc.o
# 00:01:05   CC      kernel/time/timecounter.o
# 00:01:05   CC      crypto/asymmetric_keys/asymmetric_type.o
# 00:01:05   CC      kernel/time/alarmtimer.o
# 00:01:05   CC      kernel/sched/wait_bit.o
# 00:01:05   CC      kernel/sched/swait.o
# 00:01:05   CC      drivers/acpi/acpica/exmutex.o
# 00:01:05   CC [M]  sound/firewire/bebob/bebob_pcm.o
# 00:01:05   CC      crypto/asymmetric_keys/restrict.o
# 00:01:05   AR      fs/hugetlbfs/hugetlbfs.o
# 00:01:05   CC      kernel/time/posix-stubs.o
# 00:01:05   AR      fs/hugetlbfs/built-in.o
# 00:01:05   CC      crypto/asymmetric_keys/signature.o
# 00:01:05   CC      crypto/asymmetric_keys/public_key.o
# 00:01:05   CC      kernel/sched/completion.o
# 00:01:05   CC      drivers/acpi/acpica/exnames.o
# 00:01:05   CC      drivers/acpi/acpica/exoparg1.o
# 00:01:05   CC      kernel/sched/stats.o
# 00:01:05   CC      kernel/sched/idle.o
# 00:01:06   CC [M]  sound/firewire/bebob/bebob_hwdep.o
# 00:01:06   CC      kernel/sched/debug.o
# 00:01:06   CC      fs/fuse/inode.o
# 00:01:06   ASN.1   crypto/asymmetric_keys/x509-asn1.c
# 00:01:06   ASN.1   crypto/asymmetric_keys/x509_akid-asn1.c
# 00:01:06   CC      crypto/asymmetric_keys/x509_public_key.o
# 00:01:06   CC      kernel/time/clockevents.o
# 00:01:06   CC      drivers/acpi/acpica/exoparg2.o
# 00:01:06   CC      drivers/acpi/acpica/exoparg3.o
# 00:01:06   CC      drivers/acpi/acpica/exoparg6.o
# 00:01:06   AR      crypto/asymmetric_keys/asymmetric_keys.o
# 00:01:06   CC      crypto/asymmetric_keys/x509-asn1.o
# 00:01:06   CC [M]  sound/firewire/bebob/bebob_terratec.o
# 00:01:06   CC      crypto/asymmetric_keys/x509_akid-asn1.o
# 00:01:06   CC      crypto/asymmetric_keys/x509_cert_parser.o
# 00:01:06   CC      kernel/time/tick-common.o
# 00:01:06   AR      drivers/amba/built-in.o
# 00:01:06   CC      fs/kernfs/mount.o
# 00:01:06   AR      drivers/auxdisplay/built-in.o
# 00:01:06   CC [M]  drivers/auxdisplay/charlcd.o
# 00:01:06   AR      kernel/sched/built-in.o
# 00:01:06   CC      fs/kernfs/inode.o
# 00:01:06   CC      drivers/acpi/acpica/exprep.o
# 00:01:06   CC      fs/fuse/control.o
# 00:01:07   AR      crypto/asymmetric_keys/x509_key_parser.o
# 00:01:07   AR      crypto/asymmetric_keys/built-in.o
# 00:01:07   CC      crypto/hash_info.o
# 00:01:07   CC      crypto/ablk_helper.o
# 00:01:07   CC [M]  sound/firewire/bebob/bebob_yamaha_terratec.o
# 00:01:07   CC      drivers/acpi/acpica/exregion.o
# 00:01:07   CC      drivers/base/component.o
# 00:01:07   CC      kernel/time/tick-broadcast.o
# 00:01:07   CC [M]  drivers/auxdisplay/hd44780.o
# 00:01:07   CC      fs/kernfs/dir.o
# 00:01:07   CC      fs/fuse/xattr.o
# 00:01:07   CC      drivers/acpi/acpica/exresnte.o
# 00:01:07   CC      crypto/simd.o
# 00:01:07   CC      drivers/base/core.o
# 00:01:07   CC      drivers/base/bus.o
# 00:01:07   CC      kernel/time/timekeeping_debug.o
# 00:01:07   CC [M]  sound/firewire/bebob/bebob_focusrite.o
# 00:01:07   CC      drivers/acpi/acpica/exresolv.o
# 00:01:08   CC      fs/fuse/acl.o
# 00:01:08   AR      kernel/time/built-in.o
# 00:01:08   CC      kernel/kcmp.o
# 00:01:08   CC      drivers/acpi/acpica/exresop.o
# 00:01:08   CC      fs/kernfs/file.o
# 00:01:08   CC [M]  crypto/echainiv.o
# 00:01:08   CC      fs/kernfs/symlink.o
# 00:01:08   CC [M]  sound/firewire/bebob/bebob_maudio.o
# 00:01:08   CC [M]  fs/fuse/cuse.o
# 00:01:08   CC      drivers/acpi/acpica/exstore.o
# 00:01:08   CC      drivers/acpi/acpica/exstoren.o
# 00:01:08   CC      kernel/freezer.o
# 00:01:08   AR      fs/kernfs/built-in.o
# 00:01:08   CC      drivers/acpi/acpica/exstorob.o
# 00:01:08   CC      drivers/base/dd.o
# 00:01:09   CC [M]  crypto/cmac.o
# 00:01:09   CC [M]  crypto/rmd160.o
# 00:01:09   CC [M]  sound/firewire/bebob/bebob.o
# 00:01:09   CC [M]  crypto/rmd320.o
# 00:01:09   AR      fs/fuse/fuse.o
# 00:01:09   AR      fs/fuse/built-in.o
# 00:01:09   CC      fs/nls/nls_base.o
# 00:01:09   CC      drivers/acpi/acpica/exsystem.o
# 00:01:09   CC      kernel/profile.o
# 00:01:09   CC      fs/nls/nls_cp737.o
# 00:01:09   CC      drivers/acpi/acpica/extrace.o
# 00:01:09   CC      drivers/base/syscore.o
# 00:01:09   CC      drivers/acpi/acpica/exutils.o
# 00:01:09   LD [M]  sound/firewire/bebob/snd-bebob.o
# 00:01:09   AR      sound/firewire/dice/built-in.o
# 00:01:09   CC [M]  sound/firewire/dice/dice-transaction.o
# 00:01:09   CC      fs/nls/nls_cp850.o
# 00:01:09   CC      fs/nls/nls_cp852.o
# 00:01:09   CC      fs/nls/nls_cp857.o
# 00:01:09   CC [M]  crypto/sha3_generic.o
# 00:01:09   CC      drivers/acpi/acpica/hwacpi.o
# 00:01:10   CC      kernel/stacktrace.o
# 00:01:10   CC      drivers/acpi/acpica/hwesleep.o
# 00:01:10   CC      drivers/acpi/acpica/hwgpe.o
# 00:01:10   CC      fs/nls/nls_cp860.o
# 00:01:10   CC      drivers/base/driver.o
# 00:01:10   CC      kernel/up.o
# 00:01:10   CC [M]  crypto/cts.o
# 00:01:10   CC [M]  crypto/gcm.o
# 00:01:10   CC [M]  sound/firewire/dice/dice-stream.o
# 00:01:10   CC      fs/nls/nls_cp864.o
# 00:01:10   CC      drivers/acpi/acpica/hwpci.o
# 00:01:10   CC      kernel/module.o
# 00:01:10   CC      drivers/acpi/acpica/hwregs.o
# 00:01:10   CC      drivers/base/class.o
# 00:01:10   CC      fs/nls/nls_cp866.o
# 00:01:10   CC      fs/nls/nls_cp949.o
# 00:01:10   CC      drivers/acpi/acpica/hwsleep.o
# 00:01:10   CC      drivers/acpi/acpica/hwvalid.o
# 00:01:10   CC [M]  crypto/des_generic.o
# 00:01:11   CC      drivers/base/platform.o
# 00:01:11   CC [M]  sound/firewire/dice/dice-proc.o
# 00:01:11   CC [M]  sound/firewire/dice/dice-midi.o
# ...
# 00:06:54   LD [M]  drivers/staging/comedi/drivers/mf6x4.ko
# 00:06:54   LD [M]  drivers/staging/comedi/drivers/mite.ko
# 00:06:54   LD [M]  drivers/staging/comedi/drivers/ni_6527.ko
# 00:06:54   LD [M]  drivers/staging/comedi/drivers/ni_65xx.ko
# 00:06:54   LD [M]  drivers/staging/comedi/drivers/ni_pcimio.ko
# 00:06:54   LD [M]  drivers/staging/comedi/drivers/ni_tio.ko
# 00:06:54   LD [M]  drivers/staging/comedi/drivers/ni_tiocmd.ko
# 00:06:54   LD [M]  drivers/staging/comedi/drivers/rtd520.ko
# 00:06:54   LD [M]  drivers/staging/comedi/drivers/s626.ko
# 00:06:54   LD [M]  drivers/staging/greybus/gb-gbphy.ko
# 00:06:54   LD [M]  drivers/staging/greybus/gb-gpio.ko
# 00:06:54   LD [M]  drivers/staging/greybus/gb-hid.ko
# 00:06:54   LD [M]  drivers/staging/greybus/gb-i2c.ko
# 00:06:54   LD [M]  drivers/staging/greybus/gb-power-supply.ko
# 00:06:54   LD [M]  drivers/staging/greybus/gb-sdio.ko
# 00:06:54   LD [M]  drivers/staging/most/aim-v4l2/aim_v4l2.ko
# 00:06:54   LD [M]  drivers/staging/greybus/gb-log.ko
# 00:06:54   LD [M]  drivers/staging/sm750fb/sm750fb.ko
# 00:06:54   LD [M]  drivers/staging/unisys/visorinput/visorinput.ko
# 00:06:54   LD [M]  drivers/staging/vme/devices/vme_pio2.ko
# 00:06:54   LD [M]  drivers/staging/most/hdm-i2c/hdm_i2c.ko
# 00:06:54   LD [M]  drivers/staging/vme/devices/vme_user.ko
# 00:06:54   LD [M]  drivers/staging/xgifb/xgifb.ko
# 00:06:54   LD [M]  drivers/thermal/int340x_thermal/acpi_thermal_rel.ko
# 00:06:54   LD [M]  drivers/thermal/int340x_thermal/int3400_thermal.ko
# 00:06:54   LD [M]  drivers/thermal/int340x_thermal/int3402_thermal.ko
# 00:06:54   LD [M]  drivers/thermal/int340x_thermal/int3403_thermal.ko
# 00:06:54   LD [M]  drivers/thermal/int340x_thermal/int340x_thermal_zone.ko
# 00:06:54   LD [M]  drivers/thermal/intel_powerclamp.ko
# 00:06:54   LD [M]  drivers/thermal/int340x_thermal/processor_thermal_device.ko
# 00:06:54   LD [M]  drivers/thermal/intel_soc_dts_iosf.ko
# 00:06:54   LD [M]  drivers/thermal/mtk_thermal.ko
# 00:06:54   LD [M]  drivers/thermal/rcar_thermal.ko
# 00:06:54   LD [M]  drivers/video/backlight/adp8860_bl.ko
# 00:06:54   LD [M]  drivers/video/backlight/kb3886_bl.ko
# 00:06:54   LD [M]  drivers/tty/serdev/serdev.ko
# 00:06:54   LD [M]  drivers/video/backlight/pcf50633-backlight.ko
# 00:06:54   LD [M]  drivers/video/fbdev/arcfb.ko
# 00:06:54   LD [M]  drivers/video/fbdev/arkfb.ko
# 00:06:54   LD [M]  drivers/video/fbdev/aty/radeonfb.ko
# 00:06:54   LD [M]  drivers/video/fbdev/auo_k1901fb.ko
# 00:06:54   LD [M]  drivers/video/fbdev/broadsheetfb.ko
# 00:06:54   LD [M]  drivers/video/fbdev/cirrusfb.ko
# 00:06:54   LD [M]  drivers/video/fbdev/cyber2000fb.ko
# 00:06:54   LD [M]  drivers/video/fbdev/geode/lxfb.ko
# 00:06:54   LD [M]  drivers/video/fbdev/intelfb/intelfb.ko
# 00:06:54   LD [M]  drivers/video/fbdev/neofb.ko
# 00:06:54   LD [M]  drivers/video/fbdev/ocfb.ko
# 00:06:54   LD [M]  drivers/video/fbdev/pm3fb.ko
# 00:06:54   LD [M]  drivers/video/fbdev/sis/sisfb.ko
# 00:06:54   LD [M]  drivers/video/fbdev/sm501fb.ko
# 00:06:54   LD [M]  drivers/virtio/virtio_balloon.ko
# 00:06:54   LD [M]  drivers/virtio/virtio_input.ko
# 00:06:54   LD [M]  drivers/vme/bridges/vme_fake.ko
# 00:06:54   LD [M]  drivers/w1/masters/ds1wm.ko
# 00:06:54   LD [M]  drivers/w1/slaves/w1_ds2405.ko
# 00:06:54   LD [M]  drivers/vme/bridges/vme_tsi148.ko
# 00:06:54   LD [M]  drivers/w1/slaves/w1_ds2408.ko
# 00:06:54   LD [M]  drivers/w1/slaves/w1_ds2413.ko
# 00:06:54   LD [M]  drivers/w1/slaves/w1_ds2423.ko
# 00:06:54   LD [M]  drivers/w1/slaves/w1_ds2431.ko
# 00:06:54   LD [M]  drivers/w1/slaves/w1_ds2438.ko
# 00:06:54   LD [M]  drivers/w1/slaves/w1_ds2780.ko
# 00:06:54   LD [M]  drivers/w1/slaves/w1_ds2781.ko
# 00:06:54   LD [M]  drivers/w1/slaves/w1_ds28e04.ko
# 00:06:54   LD [M]  drivers/w1/slaves/w1_smem.ko
# 00:06:54   LD [M]  drivers/w1/slaves/w1_therm.ko
# 00:06:54   LD [M]  drivers/w1/wire.ko
# 00:06:54   LD [M]  drivers/watchdog/alim7101_wdt.ko
# 00:06:54   LD [M]  drivers/watchdog/at91rm9200_wdt.ko
# 00:06:54   LD [M]  drivers/watchdog/atlas7_wdt.ko
# 00:06:54   LD [M]  drivers/watchdog/cpu5wdt.ko
# 00:06:54   LD [M]  drivers/watchdog/da9052_wdt.ko
# 00:06:54   LD [M]  drivers/watchdog/da9063_wdt.ko
# 00:06:54   LD [M]  drivers/watchdog/davinci_wdt.ko
# 00:06:54   LD [M]  drivers/watchdog/digicolor_wdt.ko
# 00:06:54   LD [M]  drivers/watchdog/eurotechwdt.ko
# 00:06:54   LD [M]  drivers/watchdog/f71808e_wdt.ko
# 00:06:54   LD [M]  drivers/watchdog/hpwdt.ko
# 00:06:54   LD [M]  drivers/watchdog/ib700wdt.ko
# 00:06:54   LD [M]  drivers/watchdog/imx2_wdt.ko
# 00:06:54   LD [M]  drivers/watchdog/it87_wdt.ko
# 00:06:54   LD [M]  drivers/watchdog/mena21_wdt.ko
# 00:06:54   LD [M]  drivers/watchdog/meson_gxbb_wdt.ko
# 00:06:54   LD [M]  drivers/watchdog/meson_wdt.ko
# 00:06:54   LD [M]  drivers/watchdog/moxart_wdt.ko
# 00:06:54   LD [M]  drivers/watchdog/ni903x_wdt.ko
# 00:06:54   LD [M]  drivers/watchdog/nic7018_wdt.ko
# 00:06:54   LD [M]  drivers/watchdog/nv_tco.ko
# 00:06:54   LD [M]  drivers/watchdog/of_xilinx_wdt.ko
# 00:06:54   LD [M]  drivers/watchdog/pcwd_pci.ko
# 00:06:54   LD [M]  drivers/watchdog/rdc321x_wdt.ko
# 00:06:54   LD [M]  drivers/watchdog/retu_wdt.ko
# 00:06:54   LD [M]  drivers/watchdog/rn5t618_wdt.ko
# 00:06:54   LD [M]  drivers/watchdog/sc1200wdt.ko
# 00:06:54   LD [M]  drivers/watchdog/s3c2410_wdt.ko
# 00:06:54   LD [M]  drivers/watchdog/sirfsoc_wdt.ko
# 00:06:54   LD [M]  drivers/watchdog/smsc37b787_wdt.ko
# 00:06:54   LD [M]  drivers/watchdog/softdog.ko
# 00:06:54   LD [M]  drivers/watchdog/tangox_wdt.ko
# 00:06:54   LD [M]  drivers/watchdog/wdat_wdt.ko
# 00:06:54   LD [M]  fs/efivarfs/efivarfs.ko
# 00:06:54   LD [M]  fs/fscache/fscache.ko
# 00:06:54   LD [M]  fs/fuse/cuse.ko
# 00:06:54   LD [M]  fs/nls/mac-cyrillic.ko
# 00:06:54   LD [M]  fs/nls/mac-gaelic.ko
# 00:06:54   LD [M]  fs/nls/mac-inuit.ko
# 00:06:54   LD [M]  fs/nls/mac-roman.ko
# 00:06:54   LD [M]  fs/nls/nls_cp1250.ko
# 00:06:54   LD [M]  fs/nls/nls_cp437.ko
# 00:06:54   LD [M]  fs/nls/nls_cp775.ko
# 00:06:54   LD [M]  fs/nls/nls_cp855.ko
# 00:06:54   LD [M]  fs/nls/nls_cp869.ko
# 00:06:54   LD [M]  fs/nls/nls_cp932.ko
# 00:06:54   LD [M]  fs/nls/nls_cp936.ko
# 00:06:54   LD [M]  fs/nls/nls_euc-jp.ko
# 00:06:54   LD [M]  fs/nls/nls_iso8859-13.ko
# 00:06:54   LD [M]  fs/nls/nls_iso8859-14.ko
# 00:06:54   LD [M]  fs/nls/nls_iso8859-15.ko
# 00:06:54   LD [M]  fs/nls/nls_iso8859-5.ko
# 00:06:54   LD [M]  fs/nls/nls_koi8-ru.ko
# 00:06:54   LD [M]  fs/nls/nls_koi8-u.ko
# 00:06:54   LD [M]  fs/nls/nls_iso8859-7.ko
# 00:06:54   LD [M]  fs/nls/nls_utf8.ko
# 00:06:54   LD [M]  kernel/backtracetest.ko
# 00:06:54   LD [M]  kernel/configs.ko
# 00:06:54   LD [M]  kernel/locking/locktorture.ko
# 00:06:54   LD [M]  kernel/torture.ko
# 00:06:54   LD [M]  lib/crc-ccitt.ko
# 00:06:54   LD [M]  lib/crc-t10dif.ko
# 00:06:54   LD [M]  lib/crc16.ko
# 00:06:54   LD [M]  lib/crc32test.ko
# 00:06:54   LD [M]  lib/crc8.ko
# 00:06:54   LD [M]  lib/libcrc32c.ko
# 00:06:54   LD [M]  lib/lz4/lz4hc_compress.ko
# 00:06:54   LD [M]  lib/notifier-error-inject.ko
# 00:06:54   LD [M]  lib/parman.ko
# 00:06:54   LD [M]  lib/percpu_test.ko
# 00:06:54   LD [M]  lib/pm-notifier-error-inject.ko
# 00:06:54   LD [M]  lib/test-string_helpers.ko
# 00:06:54   LD [M]  lib/test_firmware.ko
# 00:06:54   LD [M]  lib/test_hash.ko
# 00:06:54   LD [M]  lib/test_parman.ko
# 00:06:54   LD [M]  lib/test_siphash.ko
# 00:06:54   LD [M]  lib/test_sort.ko
# 00:06:54   LD [M]  lib/test_static_key_base.ko
# 00:06:54   LD [M]  lib/test_static_keys.ko
# 00:06:54   LD [M]  lib/xz/xz_dec_test.ko
# 00:06:54   LD [M]  mm/zsmalloc.ko
# 00:06:54   LD [M]  samples/configfs/configfs_sample.ko
# 00:06:54   LD [M]  mm/z3fold.ko
# 00:06:54   LD [M]  samples/kdb/kdb_hello.ko
# 00:06:54   LD [M]  samples/kprobes/jprobe_example.ko
# 00:06:54   LD [M]  samples/kprobes/kprobe_example.ko
# 00:06:54   LD [M]  samples/rpmsg/rpmsg_client_sample.ko
# 00:06:54   LD [M]  samples/v4l/v4l2-pci-skeleton.ko
# 00:06:54   LD [M]  sound/core/seq/snd-seq-dummy.ko
# 00:06:54   LD [M]  sound/core/seq/snd-seq-midi-emul.ko
# 00:06:54   LD [M]  sound/core/seq/snd-seq-midi-event.ko
# 00:06:54   LD [M]  sound/core/seq/snd-seq-midi.ko
# 00:06:54   LD [M]  sound/core/seq/snd-seq-virmidi.ko
# 00:06:54   LD [M]  sound/core/seq/snd-seq.ko
# 00:06:54   LD [M]  sound/drivers/opl3/snd-opl3-synth.ko
# 00:06:54   LD [M]  sound/drivers/snd-aloop.ko
# 00:06:54   LD [M]  sound/drivers/snd-dummy.ko
# 00:06:54   LD [M]  sound/drivers/snd-mtpav.ko
# 00:06:54   LD [M]  sound/drivers/snd-virmidi.ko
# 00:06:54   LD [M]  sound/drivers/vx/snd-vx-lib.ko
# 00:06:54   LD [M]  sound/firewire/bebob/snd-bebob.ko
# 00:06:54   LD [M]  sound/firewire/dice/snd-dice.ko
# 00:06:54   LD [M]  sound/firewire/digi00x/snd-firewire-digi00x.ko
# 00:06:54   LD [M]  sound/firewire/fireface/snd-fireface.ko
# 00:06:54   LD [M]  sound/firewire/motu/snd-firewire-motu.ko
# 00:06:54   LD [M]  sound/firewire/oxfw/snd-oxfw.ko
# 00:06:54   LD [M]  sound/firewire/snd-firewire-lib.ko
# 00:06:54   LD [M]  sound/pci/au88x0/snd-au8810.ko
# 00:06:54   LD [M]  sound/pci/cs5535audio/snd-cs5535audio.ko
# 00:06:54   LD [M]  sound/pci/echoaudio/snd-gina24.ko
# 00:06:54   LD [M]  sound/pci/echoaudio/snd-indigo.ko
# 00:06:54   LD [M]  sound/firewire/tascam/snd-firewire-tascam.ko
# 00:06:54   LD [M]  sound/pci/echoaudio/snd-indigodj.ko
# 00:06:54   LD [M]  sound/pci/echoaudio/snd-indigoio.ko
# 00:06:54   LD [M]  sound/pci/echoaudio/snd-layla20.ko
# 00:06:54   LD [M]  sound/pci/hda/snd-hda-codec-analog.ko
# 00:06:54   LD [M]  sound/pci/hda/snd-hda-codec-hdmi.ko
# 00:06:54   LD [M]  sound/pci/korg1212/snd-korg1212.ko
# 00:06:54   LD [M]  sound/pci/pcxhr/snd-pcxhr.ko
# 00:06:54   LD [M]  sound/pci/riptide/snd-riptide.ko
# 00:06:54   LD [M]  sound/pci/rme9652/snd-rme9652.ko
# 00:06:54   LD [M]  sound/pci/snd-atiixp-modem.ko
# 00:06:54   LD [M]  sound/pci/snd-atiixp.ko
# 00:06:54   LD [M]  sound/pci/snd-bt87x.ko
# 00:06:54   LD [M]  sound/pci/snd-cmipci.ko
# 00:06:54   LD [M]  sound/pci/snd-fm801.ko
# 00:06:54   LD [M]  sound/pci/snd-intel8x0m.ko
# 00:06:54   LD [M]  sound/pci/snd-rme96.ko
# 00:06:54   LD [M]  sound/pci/vx222/snd-vx222.ko
# 00:06:54   LD [M]  sound/soc/adi/snd-soc-adi-axi-spdif.ko
# 00:06:54   LD [M]  sound/soc/bcm/snd-soc-bcm2835-i2s.ko
# 00:06:54   LD [M]  sound/soc/bcm/snd-soc-cygnus.ko
# 00:06:54   LD [M]  sound/soc/codecs/snd-soc-mc13783.ko
# 00:06:54   LD [M]  sound/soc/codecs/snd-soc-msm8916-digital.ko
# 00:06:54   LD [M]  sound/soc/codecs/snd-soc-wm8994.ko
# 00:06:54   LD [M]  sound/soc/fsl/imx-pcm-dma.ko
# 00:06:54   LD [M]  sound/soc/fsl/snd-soc-fsl-asrc.ko
# 00:06:54   LD [M]  sound/soc/fsl/snd-soc-fsl-esai.ko
# 00:06:54   LD [M]  sound/soc/fsl/snd-soc-fsl-sai.ko
# 00:06:54   LD [M]  sound/soc/fsl/snd-soc-fsl-spdif.ko
# 00:06:54   LD [M]  sound/soc/fsl/snd-soc-fsl-ssi.ko
# 00:06:54   LD [M]  sound/soc/fsl/snd-soc-imx-spdif.ko
# 00:06:54   LD [M]  sound/soc/generic/snd-soc-simple-card.ko
# 00:06:54   LD [M]  sound/soc/hisilicon/hi6210-i2s.ko
# 00:06:54   LD [M]  sound/soc/img/img-i2s-out.ko
# 00:06:54   LD [M]  sound/soc/img/img-spdif-out.ko
# 00:06:54   LD [M]  sound/soc/img/pistachio-internal-dac.ko
# 00:06:54   LD [M]  sound/soc/intel/boards/snd-soc-skl_nau88l25_ssm4567.ko
# 00:06:54   LD [M]  sound/soc/intel/boards/snd-soc-sst-broadwell.ko
# 00:06:54   LD [M]  sound/soc/intel/boards/snd-soc-sst-bxt-rt298.ko
# 00:06:54   LD [M]  sound/soc/intel/boards/snd-soc-sst-byt-cht-es8316.ko
# 00:06:54   LD [M]  sound/soc/intel/boards/snd-soc-sst-byt-cht-nocodec.ko
# 00:06:54   LD [M]  sound/soc/intel/boards/snd-soc-sst-cht-bsw-rt5672.ko
# 00:06:54   LD [M]  sound/soc/kirkwood/snd-soc-kirkwood.ko
# 00:06:54   LD [M]  sound/soc/mxs/snd-soc-mxs-sgtl5000.ko
# 00:06:54   LD [M]  sound/soc/qcom/snd-soc-apq8016-sbc.ko
# 00:06:54   LD [M]  sound/soc/qcom/snd-soc-lpass-apq8016.ko
# 00:06:54   LD [M]  sound/soc/qcom/snd-soc-lpass-cpu.ko
# 00:06:54   LD [M]  sound/soc/qcom/snd-soc-lpass-platform.ko
# 00:06:54   LD [M]  sound/soc/samsung/snd-soc-arndale-rt5631.ko
# 00:06:54   LD [M]  sound/soc/samsung/snd-soc-littlemill.ko
# 00:06:54   LD [M]  sound/soc/samsung/snd-soc-odroid.ko
# 00:06:54   LD [M]  sound/soc/samsung/snd-soc-pcm.ko
# 00:06:54   LD [M]  sound/soc/samsung/snd-soc-s3c64xx-smartq-wm8987.ko
# 00:06:54   LD [M]  sound/soc/samsung/snd-soc-smdk-wm8994pcm.ko
# 00:06:54   LD [M]  sound/soc/samsung/snd-soc-snow.ko
# 00:06:54   LD [M]  sound/soc/samsung/snd-soc-tobermory.ko
# 00:06:54   LD [M]  sound/soc/stm/snd-soc-stm32-sai-sub.ko
# 00:06:54   LD [M]  sound/soc/stm/snd-soc-stm32-sai.ko
# 00:06:54   LD [M]  sound/soc/sunxi/sun4i-codec.ko
# 00:06:54   LD [M]  sound/soc/tegra/snd-soc-tegra-rt5640.ko
# 00:06:54   LD [M]  sound/soc/tegra/snd-soc-tegra-wm8903.ko
# 00:06:54   IHEX    firmware/korg/k1212.dsp
# 00:06:54 make: Leaving directory '/TuxML/linux-4.13.3'
#
# #########
# ERR LOG FILE
# #########
#
# #########
# OUTPUT LOG FILE
# #########
# 00:00:01 [2018-09-21 14:39:20 CEST] [args_handler] Cleaning previous compilation
# 00:00:01 make: Entering directory '/TuxML/linux-4.13.3'
# 00:00:26 make: Leaving directory '/TuxML/linux-4.13.3'
# 00:00:26 [2018-09-21 14:39:45 CEST] [get_environment_details] Getting environment details
# 00:00:26 [2018-09-21 14:39:45 CEST] [get_compilation_details] Unable to find tuxml.conf
# 00:00:27     ==> system
# 00:00:27       --> distrib_version: 9.5
# 00:00:27       --> os: Linux
# 00:00:27       --> kernel: 4.9.0-7-amd64
# 00:00:27       --> distribution: debian
# 00:00:27     ==> hardware
# 00:00:27       --> mechanical_drive: 1
# 00:00:27       --> cpu_freq: 2659
# 00:00:27       --> arch: x86_64
# 00:00:27       --> cpu_cores: 8
# 00:00:27       --> cpu: QEMU Virtual CPU version 2.1.2
# 00:00:27       --> ram: 46116700
# 00:00:27     ==> compilation
# 00:00:27       --> gcc_version: 6.3.0-18+deb9u1
# 00:00:27       --> git_branch:
# 00:00:27       --> incremental_mod: 0
# 00:00:27       --> docker_image:
# 00:00:27       --> core_used: 8
# 00:00:27       --> libc_version: 2.24-11+deb9u3
# 00:00:27       --> tuxml_version: pre-alpha v0.2
# 00:00:27 [2018-09-21 14:39:46 CEST] [get_package_manager] Finding package manager
# 00:00:27 [2018-09-21 14:39:46 CEST] [get_package_manager] Package manager is apt-get
# 00:00:27 [2018-09-21 14:39:46 CEST] [update_system] Updating packages repositories
# 00:00:34 [2018-09-21 14:39:53 CEST] [update_system] Packages repositories updated
# 00:00:34 [2018-09-21 14:39:53 CEST] [install_minimal_dependencies] Installing minimal dependencies
# 00:00:34 [2018-09-21 14:39:53 CEST] [install_packages] Installing packages : gcc make binutils util-linux e2fsprogs bc
# 00:00:34 [2018-09-21 14:39:53 CEST] [install_packages] All the packages were found and installed
# 00:00:34 [2018-09-21 14:39:53 CEST] [install_minimal_dependencies] Minimal dependencies successfully installed.
# 00:00:34 [2018-09-21 14:39:53 CEST] [install_default_dependencies] Installing default dependencies
# 00:00:34 [2018-09-21 14:39:53 CEST] [install_packages] Installing packages : kmod jfsutils xfsprogs btrfs-progs pcmciautils ppp grub iptables openssl reiserfsprogs squashfs-tools quotatool nfs-kernel-server procps mcelog libcrypto++6 apt-utils gcc-6-plugin-dev libssl-dev
# 00:00:35 [2018-09-21 14:39:54 CEST] [install_packages] All the packages were found and installed
# 00:00:35 [2018-09-21 14:39:54 CEST] [install_default_dependencies] Default dependencies successfully installed.
# 00:00:35 [2018-09-21 14:39:54 CEST] [gen_config] Randomising new KCONFIG_FILE
# 00:00:35 [2018-09-21 14:39:54 CEST] [gen_config] KCONFIG_ALLCONFIG=/TuxML/tuxml.config make -C /TuxML/linux-4.13.3 randconfig
# 00:00:40 KCONFIG_SEED=0x213DD420
# 00:00:48 [2018-09-21 14:40:07 CEST] [compilation] Compilation in progress
# 00:07:42 [2018-09-21 14:47:01 CEST] [compilation] Compilation done
# 00:07:42 [2018-09-21 14:47:01 CEST] [launcher] Successfully compiled in 00:06:53
# 00:07:42 [2018-09-21 14:47:01 CEST] [boot_try] Launching boot test on kernel
# 00:07:59 Could not initialize SDL(No available video device) - exiting
# 00:09:54 [2018-09-21 14:49:13 CEST] [boot_try] More than 60 attempts at reading, possible infinite loop in boot process, interrupting
# 00:09:54 [2018-09-21 14:49:13 CEST] [send_data] Sending compilation and tests results to database
# 00:09:54 [2018-09-21 14:49:13 CEST] [get_compressed_sizes] Computing compressed kernels
# 00:12:00 [2018-09-21 14:51:19 CEST] [send_data] Successfully sent info to db
# 00:12:00 [2018-09-21 14:51:19 CEST] [main] DATABASE CONFIGURATION ID=116732

# %%
def get_configuration_file(cid):
    print("Getting configuration file of cid=", cid)
    
    try:
        socket = MySQLdb.connect(HOST, DB_USER, DB_PASSWD, "IrmaDB_prod")
        cursor = socket.cursor()

        query = "SELECT config_file FROM Compilations WHERE cid = %d" % cid
        cursor.execute(query)
        config_file = cursor.fetchone()
        
            
        if (config_file is None):
            print ("Unable to retrieve cid=", str(cid))
            return

        try:
            return bz2.decompress(config_file[0]).decode('ascii')
        except Exception as e:
            print(str(e),"\n" + "Unable to decompress... ", file=sys.stderr)
            exit(-1)
    
    except Exception as e:
        print(str(e),"\n" + "Unable to connect to database c = " + str(cid), file=sys.stderr)
        exit(-1)
        
    finally:
        cursor.close()
        socket.close()

# also check the absence of 'n' values (ie we check whether options have no "y" values) 
def check_configuration_file_specialized(cf):
    #if cf.find('CONFIG_SLOB=y') == -1:
    #    print("SLOB is no!")    
    return all(x in cf for x in ['CONFIG_64BIT=y', "CONFIG_OPTIMIZE_INLINING=y", "CONFIG_CC_OPTIMIZE_FOR_SIZE=y"]) and not any(x in cf for x in ["CONFIG_DEBUG_INFO_DWARF4=y", "CONFIG_AIC7XXX_BUILD_FIRMWARE=y", "CONFIG_AIC79XX_BUILD_FIRMWARE=y", "CONFIG_WANXL_BUILD_FIRMWARE=y", "CONFIG_LOCK_STAT=y", "CONFIG_X86_VSMP=y", "CONFIG_DEBUG_INFO=y", "CONFIG_DEBUG_INFO_SPLIT=y", "CONFIG_UBSAN_SANITIZE_ALL=y", "CONFIG_GCOV_PROFILE_ALL=y", "CONFIG_DEBUG_INFO_REDUCED=y", "CONFIG_RANDOMIZE_BASE=y", "CONFIG_X86_NEED_RELOCS=y", "CONFIG_KASAN_OUTLINE=y", "CONFIG_UBSAN_ALIGNMENT=y", "CONFIG_USB_SERIAL_OPTICON=y", "CONFIG_KASAN=y", "CONFIG_KCOV_INSTRUMENT_ALL=y", "CONFIG_XFS_DEBUG=y", "CONFIG_MAXSMP=y"])                                                                                                                                                    
# TODO: issues with these options:
# "CONFIG_SLOB=y" (seems not necessarily active)
## and these one that are apparently sometimes yes (despite being forced to no)
# "CONFIG_FW_LOADER_USER_HELPER"
# "CONFIG_STRICT_MODULE_RWX" 
## see below

# TODO: integrate in check_configuration_file_specialized
def check_spe_capricious_option(cf):
        return all(x in cf for x in ['CONFIG_SLOB=y']) and not any(x in cf for x in ["CONFIG_FW_LOADER_USER_HELPER=y", "CONFIG_STRICT_MODULE_RWX=y"])

cf1 = get_configuration_file(116733) #78749: WANXL_BUILD_FIRMWARE # 79052 AIC7XXX_BUILD_FIRMWARE
assert (check_configuration_file_specialized(cf1))


assert(check_configuration_file_specialized(get_configuration_file(116732)))
assert(check_configuration_file_specialized(get_configuration_file(116734)))
assert(check_configuration_file_specialized(get_configuration_file(116735)))
assert(check_configuration_file_specialized(get_configuration_file(116736)))

#fail = 0
#for i in range (123000, 124000):
#    if (not check_configuration_file_specialized(get_configuration_file(i))):
#        fail = fail + 1
#        print ("Specialization fails: ", fail)
        


#get_configuration_file(119997)
# Out:
# Getting configuration file of cid= 116733
# Getting configuration file of cid= 116732
# Getting configuration file of cid= 116734
# Getting configuration file of cid= 116735
# Getting configuration file of cid= 116736

# %%
# interestingly, for the "preset" options, options tinyconfig = options allnoconfig + our options spe
cf_allno_preset = get_configuration_file(124976)
check_configuration_file_specialized(cf_allno_preset), check_spe_capricious_option(cf_allno_preset)

cf_tinyconfig_x64 = get_configuration_file(88035)
check_configuration_file_specialized(cf_tinyconfig_x64), check_spe_capricious_option(cf_tinyconfig_x64)

# a "basic" make allnoconfig with only one presetting: X64
cf_allno_x64 = get_configuration_file(124978)
check_configuration_file_specialized(cf_allno_x64), check_spe_capricious_option(cf_allno_x64)

# TODO: compare .config (with the utility of Linux kernel)
# Out:
# Getting configuration file of cid= 124976
# Getting configuration file of cid= 88035
# Getting configuration file of cid= 124978
# (False, False)

# %%
# UNCOMMENT if you want to extract/build a CSV out of the database
#if __name__ == "__main__":
    
    # Change values to append a new range of data from db to the csv
#    From = 20000 #100000 #30000 #15000 # 40510 56580 # 
#    To = 30000 #104500 #99400 #94390 #88036 #80054 # 78900 # 56593 # 
    
#    subprocess.run("rm config_bdd.csv", shell=True)
    
#    if not os.path.exists("config_bdd.csv"):
#        create_header()
#        print("config_bdd.csv created", flush=True)
#    
#    print("From %d to %d" % (From, To))
#    to_csv(From, To)
#    print("\nWritten!")
    
#    """
#    with open("config_bdd.csv", "r") as file:
#        t = file.readlines()
#        lines = []
#        for i in range(len(t)):
#            lines.append(t[i].split(","))
#    """
